# %%
import numpy as np
import matplotlib.pyplot as plt

from matplotlib.ticker import MaxNLocator
from collections import namedtuple

# import chinese
# chinese.set_ch()
def set_ch():
    from pylab import mpl
    mpl.rcParams['font.sans-serif'] = ['FangSong'] # 指定默认字体
    mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像是负号'-'显示为方块的问题
set_ch()

# %%
# Example data
np.random.seed(19680801)

people = ('Tom', 'Dick', 'Harry', 'Slim', 'Jim')
y_pos = np.arange(len(people))
performance = 3 + 10 * np.random.rand(len(people))
error = np.random.rand(len(people))

# %%
n_groups = 5

means_men = (20, 35, 30, 35, 27)
std_men = (2, 3, 4, 1, 2)

means_women = (25, 32, 34, 20, 25)
std_women = (3, 5, 2, 3, 3)

# %%
fig, axes = plt.subplots(2, 2, figsize=(10,10))
# ax0, ax1, ax2, ax3 = axes.flatten()

fig.suptitle('How fast do you want to go today?', fontsize=20)
# fig.tight_layout()

index = np.arange(n_groups)
bar_width = 0.35
opacity = 0.4 # alpha = 0.4
error_config = {'ecolor': '0.3'}

# ax1
ax = axes[0][0]
ax.bar(y_pos, performance, yerr=error, align='center',
        color='green', ecolor='black')
ax.set_xticks(y_pos)
ax.set_xticklabels(people)
ax.invert_xaxis()  # labels read top-to-bottom
ax.set_ylabel('Performance')
ax.set_title('How fast do you want to go today?', loc = 'left')

# ax2
ax = axes[0][1]
ax.barh(y_pos, performance, xerr=error, align='center',
        color='y', ecolor='black')
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.invert_yaxis()
ax.set_xlabel('Performance')
ax.set_title('How fast do you want to go today?', color = 'r')

# ax3
ax = axes[1][0]
rects1 = ax.bar(index, means_men, bar_width,
                alpha=opacity, color='b',
                yerr=std_men, error_kw=error_config,
                label='Men')

rects2 = ax.bar(index + bar_width, means_women, bar_width,
                alpha=opacity, color='r',
                yerr=std_women, error_kw=error_config,
                label='Women')

ax.set_xlabel('Group')
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender', color = 'r', alpha = opacity)
ax.set_xticks(index + bar_width / 2)
ax.set_xticklabels(('A', 'B', 'C', 'D', 'E'))
ax.legend()

# ax4
ax = axes[1][1]
p1 = ax.bar(index, means_men, bar_width, yerr=std_men)
p2 = ax.bar(index, means_women, bar_width,
             bottom=means_men, yerr=std_women)

ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender', color = 'r', verticalalignment ='top')
ax.set_xticks(index, ('G1', 'G2', 'G3', 'G4', 'G5'))
ax.set_yticks(np.arange(0, 81, 10))
ax.legend((p1[0], p2[0]), ('Men', 'Women'))

plt.show()

# %%
name1 = ['主动型','感悟型','视觉型','渐进型']
name2 = ['反思型','直觉型','语言型','整体型']

score1 = [11,10,5,2]
score2 = [0,1,6,9]
score3 = [0,0,0,0]

# %%
fig, ax = plt.subplots()

index = np.arange(len(name1))

p1 = ax.barh(index, score1)
p2 = ax.barh(index, score2, left = score1)

ax.set_yticks(index)
ax.set_yticklabels(name1, fontsize = 15)
ax.invert_yaxis()  # labels read top-to-bottom

ax2 = ax.twinx()  # this is the important function
ax2.barh(index, score3)
ax2.set_yticks(index)
ax2.set_yticklabels(name2, fontsize = 15)
ax2.invert_yaxis()  # labels read top-to-bottom

# plt.axvline(x=5.5, ymin=0, linewidth=2, color='g',ls = '--')
plt.xticks([])
i = 0
for s in score1:
    if s == 0:
        j += 1
        continue
    else :
        plt.text(s/2,i,'%d%%' % (round(s/11*100)), fontsize = 15, horizontalalignment='center',verticalalignment='center',)
    i += 1

j = 0
for s in score2:
    if s == 0:
        j += 1
        continue        
    else :
        plt.text((11 - s) + s/2,j,'%d%%' % (round(s/11*100)), fontsize = 15, horizontalalignment='center',verticalalignment='center',)
    j += 1
    
plt.show()
