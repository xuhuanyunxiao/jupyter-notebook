# %% [markdown]
# - 保监会 相关性模型 3 测试

# %% [markdown]
# # 基本设置

# %%
##load packages, needed
# encoding=utf-8

import jieba
import sys
import re
import time
import string
from sklearn import feature_extraction
from sklearn.pipeline import Pipeline,FeatureUnion

from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_selection import SelectKBest, chi2,mutual_info_classif,f_classif

import pickle  

from sklearn.datasets.base import Bunch
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import confusion_matrix, f1_score
from sklearn.ensemble import ExtraTreesClassifier

import xgboost as xgb
from xgboost import XGBClassifier
from sklearn import metrics

from sklearn.base import BaseEstimator, TransformerMixin
from collections import defaultdict

import joblib

import numpy as np
import pandas as pd
import pre_cor
import os
from sklearn.model_selection import train_test_split
from sqlalchemy import create_engine
from pandas.io import sql
import requests,json
from sklearn.externals import joblib

import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 一些函数

# %%
def set_ch():
    '''
    功能：设定绘图时显示中文
    '''	
    from pylab import mpl
    mpl.rcParams['font.sans-serif'] = ['FangSong'] # 指定默认字体
    mpl.rcParams['axes.unicode_minus'] = False   # 解决保存图像是负号'-'显示为方块的问题
set_ch()

# %%
class StatsFeatures_cor(BaseEstimator, TransformerMixin):
    
    def __init__(self):
        self.neg = set()
        f = open("corpus/neg_words.txt","r+", encoding='UTF-8')
        for content in f:
            self.neg.add(content.strip())
        f.close()
        
        self.company = set() # 公司
        f = open("corpus/insurance_company_20180803.txt","r+", encoding='UTF-8')
        for content in f:
            self.company.add(content.strip())
        f.close()

        self.regulators = set() # 监管机构及领导
        f = open("corpus/insurance_regulators_20180804.txt","r+", encoding='UTF-8')
        for content in f:
            self.regulators.add(content.strip())
        f.close()    
        
        #初始化字典liwc
        self.liwc = {} 
        f2 = open("corpus/scliwc.txt",'r', encoding = 'gb18030')
        for ii in f2:     #ii在scliwc.txt中循环
            i = ii.strip().split() 
            self.liwc[i[0]] = i[1:len(i)]
        f2.close      
        
        self.category = set()
        for i in list(self.liwc.values()):
            for j in i:
                self.category.add(j)         
        
    def fit(self, X, y=None):
        return self

    def getcnt(self,x):        
        return len(list(set(x)))

    def getnegcnt(self,x):
        negcnt = 0
        words = x.split()
        for w in words:
            if w in self.neg:
                negcnt = negcnt+1
        return negcnt
    
    def getorgcnttf(self,x):
        companycnt=0
        companytf=0
        regcnt = 0
        regtf = 0
        
        words = x.split()
        words_set=set(words)
        for w in words_set:
            if w in self.company:
                companycnt = companycnt+1
                companytf=companytf+words.count(w)
                
            if w in self.regulators:
                regcnt = regcnt+1
                regtf=regtf+words.count(w)            
                
        return companycnt, companytf, regcnt, regtf
    
    def transform(self, X):
        data = []
        for x in X:
            if len(x) == 0:
                length  = 1
            else :
                length = len(x)
                
            companycnt, companytf, regcnt, regtf=self.getorgcnttf(x)
            
            words = x.split()
            psy = []
            for w in words:
                if w in self.liwc: #是否liwc字典包含分词结果列表words的哪些分词
                    psy += self.liwc[w] 
            
            cat_tf = []
            for cat in self.category:
                cat_tf.append(psy.count(cat)) 
                
            data.append([len(x),self.getcnt(x),self.getcnt(x)/length,
                         self.getnegcnt(x),self.getnegcnt(x)/length,
                         companycnt, companytf, regcnt, regtf] + cat_tf)            
        return data

# %%
def getkeywords(X, N = 1000):
    '''
    训练时生成，合并所有记录，取N个关键词
    '''
    textrank = analyse.textrank

    text_combined = ' '.join(X)
    keywords = textrank(text_combined, topK = N)
    print('keywords num: ', len(keywords))
    if len(keywords) < N : 
        N  = len(keywords)

    if keywords:
        f = open("corpus/keywords.txt","w+", encoding='UTF-8')
        for content in keywords:
            content = content.strip()
            f.write(content + '\n')
        f.close()

# %%
class Statskeywords(BaseEstimator, TransformerMixin):
    
    def __init__(self, topk = 100):
        self.topk = topk
#         print(self.topk)
        self.keywords = set()
        f = open("corpus/keywords.txt","r+", encoding='UTF-8')
        num = 0
        for content in f:
            if num < topk:
                self.keywords.add(content.strip().replace('\n', ''))
            num += 1
        f.close() 
                
        self.otherwords = ['保险业','保险行业','保费','险资','险企', # 行业
                           '罚款', # 公司 
                           '产品', '销售', '投保', '保单', '续保', # 产品
                           '投诉','骗保','案例','快速理赔','快赔','赔付', # 消费
                           '个股','港股','股市','股票','大盘','目标价','评级', # 资本
                           '活动','扶贫','奖','批复' # 其他
                          ]
    
    def fit(self, X, y=None):
        return self 
    
    def transform(self, X):
        '''
        文本中关键词的词频
        '''                        
        data = []
        for x in X:
            words = x.split()
            word_tf = []
            keycnt = 0
            for kw in self.keywords:
                word_tf.append(words.count(kw)) # 各个关键词的词频
                if kw in words:keycnt+=1
            word_tf.append(keycnt) # 关键词的个数
            
            tw_tf = []
            for tw in self.otherwords:
                tw_tf.append(words.count(tw))               
                
            data.append(word_tf + tw_tf)            
        return data

# %%
def classified_index(corpus_p, corpus_n, corpus, lab, chapter_pipeline_1):
    '''
    二分类模型各指标的结果
    '''
    
    res = chapter_pipeline_1.predict(corpus_p)
    print('正样本预测准确率: ', float(sum(res))/len(res),len(res))
    
    res = chapter_pipeline_1.predict(corpus_n)
    print('负样本预测准确率: ',  1-float(sum(res))/len(res),len(res))
    
    y_pred_class = chapter_pipeline_1.predict(corpus)
    print('accuracy_score: ', metrics.accuracy_score(lab, y_pred_class)) # 指所有分类正确的百分比
    print(metrics.classification_report(lab, y_pred_class))
    print('confusion_matrix: ')
    print( metrics.confusion_matrix(lab, y_pred_class))

# %%
def set_ch():
    '''
    功能：设定绘图时显示中文
    '''	
    from pylab import mpl
    mpl.rcParams['font.sans-serif'] = ['FangSong'] # 指定默认字体
    mpl.rcParams['axes.unicode_minus'] = False   # 解决保存图像是负号'-'显示为方块的问题
set_ch()

# %%
def get_server_res(data, url):
    '''
    服务器接口测试程序
    传入 dict, 传出 DataFrame
    '''
    # data = {'record':[{'id':0,'title':'ss','content':'zzz'},]}
    # data = {"record":marked_human_data.iloc[:5,:3].to_dict(orient = 'records')}
    # url "http://47.93.77.19:10000/correlation_negative"
    headers={'content-type':'application/json'}
    result = requests.post(url,
                      data = json.dumps(data),
                      headers=headers, allow_redirects=True)
    # print(result.text)
    json_data = json.loads(result.text)
    parse_data = []
    elapsed_time = json_data['elapsed_time']
    for i in range(len(json_data['docs'])):
        parse_data.append([json_data['docs'][i]['id'],
                          json_data['docs'][i]['cor']])
    parse_data = pd.DataFrame(parse_data, columns = ['id', 'cor'])    
    return parse_data, elapsed_time

# %% [markdown]
# # 测试模型

# %% [markdown]
# - 导入数据测试八分类模型结果

# %% [markdown]
# ## 获取一天数据

# %%
DB_CON_STR = 'mysql+pymysql://wisedb:Wi$eWeb123@47.95.148.133:5718/pom?charset=utf8'  
engine = create_engine(DB_CON_STR, echo=False)

# %%
day_select = '2018-08-07'

# %% [markdown]
# ### 之前算法判断为相关

# %%
sql_circ_cor_one_day = "select t1.id, t1.publishtime, t1.title,t2.center as content \
                            from wise_web_docinfo t1, wise_web_docinfo_center t2 \
                                where t1.id = t2.doc_id \
                                  and date_format(t1.publishtime, '%%Y-%%m-%%d') = '{0}'".format('2018-08-07')
# 实际
circ_cor = pd.read_sql(sql_circ_cor_one_day, engine)
print(circ_cor.shape)
circ_cor.head()
# Out:
# (6256, 4)
#         id         publishtime                                        title  \
# 0  9996545 2018-08-07 00:01:01    2018.8.6丨麦肯锡：2030年保险代理人数量大幅减少；80余家险企迎现场检查
# 1  9996546 2018-08-07 00:01:32         860亿国资系平台深夜暴雷，经侦介入，用户超900万人，曾宣称将赴港上市
# 2  9996623 2018-08-07 00:10:41  友邦用数字说话！充裕未来实现率100%+，其终期红利／ 终期分红的红利／分红率将会增加
# 3  9996626 2018-08-07 00:11:02                      电梯买了保险，维修成本下降50%，怎么实现的？
# 4  9996628 2018-08-07 00:10:47                     香港保险快讯 ︳友邦保险 调高2018年红利分派
#
#                                              content
# 0  二季度超六成中小财险公司偿付能力下滑 二季度，财险业并未出现偿付能力不达标的险企。不过，依旧...
# 1  点击蓝字关注这个神奇的公众号～ 7月31日晚间，经多方消息确认，杭州网贷平台草根投资已由公安...
# 2  香港友邦分红高于实际演示，用事实说明了众多客户的选择是多么的明智！ 以下重点为大家呈现！ 对...
# 3  《财经》杂志最近刊发了一篇标题为《以市场化手段破解难点 宁波市保险创新取得重大突破》的文章，...
# 4  2018年红利实现率报告 经常有人问买分红的理财性保险计划，选那间保险公司好！？ 友邦保险以...

# %%
sql_one_day = "select t1.titlehash, count(distinct t1.titlehash) as count, \
                    t1.id, t1.title,t2.center as content, t1.publishtime as publishtime \
                    from wise_web_docinfo t1, wise_web_docinfo_center t2 \
                        where t1.id=t2.doc_id \
                              and date_format(t1.publishtime, '%%Y-%%m-%%d') = '{0}' \
                              group by t1.titlehash".format(day_select)

# titlehash 去重后
circ_cor = pd.read_sql(sql_one_day, engine)
print(circ_cor.shape  )
circ_cor.head()
# Out:
# (2572, 6)
#              titlehash  count        id                               title  \
# 0 -9195559370349617446      1  10068070                  银保监会：严打非法放贷、转贷、校园贷
# 1 -9184038910511438683      1  10011147  中信银行哈尔滨遭罚400万 违法核保存单质押承兑汇票-中国质量新闻网
# 2 -9180579505846388039      1  10054400                 “保险科技”大爆发，香港又要落后一步？
# 3 -9170661681993159398      1  10010635                   人民日报：稳金融，更好服务实体经济
# 4 -9170388180645568119      1  10037524                    保险股集体大涨 中国人寿涨逾4%
#
#                                              content         publishtime
# 0                                 银保监会：严打非法放贷、转贷、校园贷 2018-08-07 22:50:10
# 1  中国经济网北京8月6日讯 8月3日，银保监会网站公布的黑龙江银监局行政处罚信息公开表显示，中... 2018-08-07 10:54:42
# 2  扫一扫，关注我 前言 2018年7月6日，在北京召开了“中国首届科技赋能保险中介大会”，这次... 2018-08-07 05:59:11
# 3  　　上半年对实体经济发放的人民币贷款增加8.76万亿元，同比增5548亿元——　　稳金融，更... 2018-08-07 09:33:20
# 4  (图片)　　证券时报网（www.stcn.com）12月02日讯　　保险股集体大涨，截至发稿... 2018-08-07 18:39:39

# %%
# 本地模型
data = {"record":circ_cor.loc[:,['id', 'title' ,'content']].to_dict(orient = 'records')}
url = "http://192.168.0.104:11000/judge_correlation_i"
# url = "http://47.93.77.19:10001/judge_correlation_i"
parse_data, elapsed_time = get_server_res(data, url)
print('elapsed_time: ', elapsed_time)
parse_data.head()
# Out:
# elapsed_time:  143.00
#          id  cor
# 0  10068070    8
# 1  10011147    8
# 2  10054400    2
# 3  10010635    1
# 4  10037524    5

# %%
label_dic={'监管':1,'行业':2,'产品销售':3,'资本市场':4,'公司内部管理':5,'消费服务':6,'其他相关报道':7,'噪音':8}
class_name_dict = {v: k for k, v in label_dic.items()}
class_name_dict
# Out:
# {1: '监管',
#  2: '行业',
#  3: '产品销售',
#  4: '资本市场',
#  5: '公司内部管理',
#  6: '消费服务',
#  7: '其他相关报道',
#  8: '噪音'}

# %%
parse_data.columns = ['id', 'predict_label']
parse_data['predict_label'] = parse_data['predict_label'].apply(lambda x:class_name_dict[x])
parse_data['label'] = ''
parse_data.head()
# Out:
#          id predict_label label
# 0  10068070            噪音
# 1  10011147            噪音
# 2  10054400            行业
# 3  10010635            监管
# 4  10037524        公司内部管理

# %%
combined_cor = pd.merge(parse_data, circ_cor, on = 'id', how = 'inner')
combined_cor.head()
# Out:
#          id predict_label label            titlehash  count  \
# 0  10068070            噪音       -9195559370349617446      1
# 1  10011147            噪音       -9184038910511438683      1
# 2  10054400            行业       -9180579505846388039      1
# 3  10010635            监管       -9170661681993159398      1
# 4  10037524        公司内部管理       -9170388180645568119      1
#
#                                 title  \
# 0                  银保监会：严打非法放贷、转贷、校园贷
# 1  中信银行哈尔滨遭罚400万 违法核保存单质押承兑汇票-中国质量新闻网
# 2                 “保险科技”大爆发，香港又要落后一步？
# 3                   人民日报：稳金融，更好服务实体经济
# 4                    保险股集体大涨 中国人寿涨逾4%
#
#                                              content         publishtime
# 0                                 银保监会：严打非法放贷、转贷、校园贷 2018-08-07 22:50:10
# 1  中国经济网北京8月6日讯 8月3日，银保监会网站公布的黑龙江银监局行政处罚信息公开表显示，中... 2018-08-07 10:54:42
# 2  扫一扫，关注我 前言 2018年7月6日，在北京召开了“中国首届科技赋能保险中介大会”，这次... 2018-08-07 05:59:11
# 3  　　上半年对实体经济发放的人民币贷款增加8.76万亿元，同比增5548亿元——　　稳金融，更... 2018-08-07 09:33:20
# 4  (图片)　　证券时报网（www.stcn.com）12月02日讯　　保险股集体大涨，截至发稿... 2018-08-07 18:39:39

# %%
combined_cor['predict_label'].value_counts()
# Out:
# 监管        825
# 噪音        817
# 行业        308
# 公司内部管理    224
# 消费服务      184
# 其他相关报道    101
# 资本市场       74
# 产品销售       39
# Name: predict_label, dtype: int64

# %%
combined_cor.drop(['titlehash', 'count'], axis = 1).to_excel('data/result/cor_predict_%s.xlsx'%day_select, index = False)

# %%
day_list = ['2018-08-03','2018-08-04','2018-08-05','2018-08-06']

# %%
import datetime
start='2018-07-01'
end='2018-07-21'
 
datestart=datetime.datetime.strptime(start,'%Y-%m-%d')
dateend=datetime.datetime.strptime(end,'%Y-%m-%d')
 
day_list = []
while datestart<dateend:
    datestart+=datetime.timedelta(days=1)
    day_list.append(datestart.strftime('%Y-%m-%d'))
    
day_list
# Out:
# ['2018-07-02',
#  '2018-07-03',
#  '2018-07-04',
#  '2018-07-05',
#  '2018-07-06',
#  '2018-07-07',
#  '2018-07-08',
#  '2018-07-09',
#  '2018-07-10',
#  '2018-07-11',
#  '2018-07-12',
#  '2018-07-13',
#  '2018-07-14',
#  '2018-07-15',
#  '2018-07-16',
#  '2018-07-17',
#  '2018-07-18',
#  '2018-07-19',
#  '2018-07-20',
#  '2018-07-21']

# %%
for day_select in day_list:
    print('-- day_select: ', day_select)
    sql_one_day = "select t1.titlehash, count(distinct t1.titlehash) as count, \
                    t1.id, t1.title,t2.center as content, t1.publishtime as publishtime \
                    from wise_web_docinfo t1, wise_web_docinfo_center t2 \
                        where t1.id=t2.doc_id \
                              and date_format(t1.publishtime, '%%Y-%%m-%%d') = '{0}' \
                              group by t1.titlehash".format(day_select)
    circ_cor = pd.read_sql(sql_one_day, engine)
    print('circ_cor: ', circ_cor.shape)
    data = {"record":circ_cor.loc[:,['id', 'title' ,'content']].to_dict(orient = 'records')}
    url = "http://192.168.0.104:11000/judge_correlation_i"
#     url = "http://47.93.77.19:10001/judge_correlation_i"
    parse_data, elapsed_time = get_server_res(data, url)
    print('elapsed_time: ', elapsed_time)
    parse_data.columns = ['id', 'predict_label']
    parse_data['predict_label'] = parse_data['predict_label'].apply(lambda x:class_name_dict[x])
    parse_data['label'] = ''
    combined_cor = pd.merge(parse_data, circ_cor, on = 'id', how = 'inner')
    combined_cor.drop(['titlehash', 'count'], axis = 1).to_excel('data/result/cor_predict_%s.xlsx'%day_select, index = False)
    print(combined_cor['predict_label'].value_counts())
# Out:
# -- day_select:  2018-07-02
# circ_cor:  (2630, 6)
# elapsed_time:  90.00
# 噪音        1095
# 监管         450
# 消费服务       249
# 行业         241
# 其他相关报道     207
# 公司内部管理     191
# 产品销售        99
# 资本市场        98
# Name: predict_label, dtype: int64
# -- day_select:  2018-07-03
# circ_cor:  (2795, 6)
# elapsed_time:  98.00
# 噪音        1161
# 监管         473
# 消费服务       266
# 其他相关报道     264
# 行业         252
# 公司内部管理     169
# 产品销售       110
# 资本市场       100
# Name: predict_label, dtype: int64
# -- day_select:  2018-07-04
# circ_cor:  (2587, 6)
# elapsed_time:  83.00
# 噪音        945
# 监管        346
# 消费服务      344
# 其他相关报道    254
# 行业        245
# 公司内部管理    207
# 产品销售      128
# 资本市场      118
# Name: predict_label, dtype: int64
# -- day_select:  2018-07-05
# circ_cor:  (3287, 6)
# elapsed_time:  91.00
# 噪音        1376
# 消费服务       494
# 监管         385
# 其他相关报道     291
# 行业         264
# 公司内部管理     205
# 资本市场       161
# 产品销售       111
# Name: predict_label, dtype: int64
# -- day_select:  2018-07-06
# circ_cor:  (3378, 6)
# elapsed_time:  108.00
# 噪音        1205
# 监管         496
# 消费服务       491
# 其他相关报道     363
# 行业         338
# 公司内部管理     219
# 资本市场       147
# 产品销售       119
# Name: predict_label, dtype: int64
# -- day_select:  2018-07-07
# circ_cor:  (2159, 6)
# elapsed_time:  108.00
# 噪音        883
# 监管        429
# 消费服务      227
# 其他相关报道    205
# 行业        165
# 公司内部管理    108
# 资本市场       83
# 产品销售       59
# Name: predict_label, dtype: int64
# -- day_select:  2018-07-08
# circ_cor:  (2083, 6)
# elapsed_time:  118.00
# 噪音        752
# 监管        462
# 其他相关报道    398
# 消费服务      157
# 行业        138
# 资本市场       71
# 公司内部管理     65
# 产品销售       40
# Name: predict_label, dtype: int64
# -- day_select:  2018-07-09
# circ_cor:  (4164, 6)
# elapsed_time:  225.00
# 噪音        1374
# 监管         940
# 其他相关报道     807
# 行业         372
# 消费服务       254
# 公司内部管理     182
# 资本市场       173
# 产品销售        62
# Name: predict_label, dtype: int64
# -- day_select:  2018-07-10
# circ_cor:  (4407, 6)
# elapsed_time:  248.00
# 噪音        1497
# 监管        1025
# 其他相关报道     739
# 行业         335
# 消费服务       316
# 公司内部管理     246
# 资本市场       167
# 产品销售        82
# Name: predict_label, dtype: int64
# -- day_select:  2018-07-11
# circ_cor:  (4070, 6)
# elapsed_time:  243.00
# 噪音        1508
# 监管         799
# 其他相关报道     624
# 行业         368
# 消费服务       311
# 公司内部管理     260
# 资本市场       128
# 产品销售        72
# Name: predict_label, dtype: int64
# -- day_select:  2018-07-12
# circ_cor:  (3336, 6)
# elapsed_time:  215.00
# 噪音        1391
# 其他相关报道     490
# 监管         464
# 行业         299
# 消费服务       270
# 公司内部管理     261
# 资本市场       111
# 产品销售        50
# Name: predict_label, dtype: int64
# -- day_select:  2018-07-13
# circ_cor:  (3514, 6)
# elapsed_time:  183.00
# 噪音        1415
# 其他相关报道     544
# 监管         510
# 消费服务       340
# 行业         302
# 公司内部管理     223
# 资本市场       107
# 产品销售        73
# Name: predict_label, dtype: int64
# -- day_select:  2018-07-14
# circ_cor:  (1614, 6)
# elapsed_time:  94.00
# 噪音        730
# 监管        288
# 消费服务      153
# 其他相关报道    144
# 行业        141
# 公司内部管理     97
# 资本市场       35
# 产品销售       26
# Name: predict_label, dtype: int64
# -- day_select:  2018-07-15
# circ_cor:  (1072, 6)
# elapsed_time:  66.00
# 噪音        450
# 监管        211
# 消费服务      107
# 其他相关报道    103
# 行业         96
# 公司内部管理     50
# 产品销售       28
# 资本市场       27
# Name: predict_label, dtype: int64
# -- day_select:  2018-07-16
# circ_cor:  (2617, 6)
# elapsed_time:  148.00
# 噪音        1140
# 监管         400
# 其他相关报道     317
# 行业         247
# 消费服务       243
# 公司内部管理     166
# 资本市场        64
# 产品销售        40
# Name: predict_label, dtype: int64
# -- day_select:  2018-07-17
# circ_cor:  (2811, 6)
# elapsed_time:  163.00
# 噪音        1180
# 监管         504
# 其他相关报道     295
# 消费服务       254
# 行业         246
# 公司内部管理     203
# 资本市场        81
# 产品销售        48
# Name: predict_label, dtype: int64
# -- day_select:  2018-07-18
# circ_cor:  (2969, 6)
# elapsed_time:  170.00
# 噪音        1296
# 监管         594
# 其他相关报道     266
# 行业         251
# 消费服务       237
# 公司内部管理     182
# 资本市场        78
# 产品销售        65
# Name: predict_label, dtype: int64
# -- day_select:  2018-07-19
# circ_cor:  (3609, 6)
# elapsed_time:  266.00
# 噪音        1448
# 监管         834
# 行业         315
# 其他相关报道     299
# 消费服务       239
# 资本市场       222
# 公司内部管理     199
# 产品销售        53
# Name: predict_label, dtype: int64
# -- day_select:  2018-07-20
# circ_cor:  (4254, 6)
# elapsed_time:  319.00
# 噪音        1372
# 监管        1247
# 其他相关报道     504
# 行业         321
# 公司内部管理     261
# 资本市场       243
# 消费服务       242
# 产品销售        64
# Name: predict_label, dtype: int64
# -- day_select:  2018-07-21
# circ_cor:  (2678, 6)
# elapsed_time:  204.00
# 监管        1152
# 噪音         625
# 其他相关报道     297
# 消费服务       153
# 行业         144
# 公司内部管理     139
# 资本市场       118
# 产品销售        50
# Name: predict_label, dtype: int64

# %%
# day_list = ['2018-08-03','2018-08-04','2018-08-05','2018-08-06','2018-08-07']

combined_cor = pd.DataFrame()
for day_select in day_list:
    tmp_data = pd.read_excel('data/result/cor_predict_%s.xlsx'%day_select)
    combined_cor = pd.concat([combined_cor, tmp_data], axis = 0)
    
print(combined_cor.shape)  
print(combined_cor['predict_label'].value_counts())
combined_cor.head()
# Out:
# (60034, 6)
# 噪音        22843
# 监管        12009
# 其他相关报道     7411
# 消费服务       5347
# 行业         5080
# 公司内部管理     3633
# 资本市场       2332
# 产品销售       1379
# Name: predict_label, dtype: int64
#         id predict_label  label  \
# 0  9723642          产品销售    NaN
# 1  9727376        其他相关报道    NaN
# 2  9727666            行业    NaN
# 3  9729854            噪音    NaN
# 4  9728364          资本市场    NaN
#
#                                                title  \
# 0  尖瘦代餐饼干安全吗？\n答案是：绝对安全‼️\n\n尖瘦有1000万太平洋保险承保，如检测出...
# 1                     【7.8怎么玩？】温州保险业“我为78点个赞”手指舞视频展示
# 2                                  北新建材半年报预增60%-100%
# 3                         上半年银监系统开出超1600张罚单 罚没超10亿元！
# 4                             招商银行：安邦财险拟将12.59亿股A股转让
#
#                                              content         publishtime
# 0  尖瘦代餐饼干安全吗？\n答案是：绝对安全‼️\n\n尖瘦有1000万太平洋保险承保，如检测出... 2018-07-02 00:57:53
# 1  我为7.8点个赞                厉害了，我的祖国，这里有保险力量?厉害了，我... 2018-07-02 18:13:11
# 2  北新建材公告，预计2018年半年度实现归属于上市公司股东的净利润为10.9172亿元-13.... 2018-07-02 17:53:58
# 3  2018年已过半，银监系统最大罚单开给了谁？最多数量的罚单剑指哪类案由？千万级罚单又被谁“收... 2018-07-02 19:23:34
# 4  【招商银行：安邦财险拟将12.59亿股A股转让给和谐健康保险】招商银行晚间公告称，安邦财险与... 2018-07-02 19:14:24

# %%
fea_filename = 'data/result/cor_predict_class_20180810(0702-0701).xlsx'
with pd.ExcelWriter(fea_filename) as writer:
    for label in combined_cor['predict_label'].unique():
        tmp_data = combined_cor[combined_cor['predict_label'] == label]
#         if tmp_data.shape[0] > 5000:
#             N = 5000
#         else :
#             N = tmp_data.shape[0]
        if label in ['产品销售','资本市场','行业','公司内部管理']:
            N = tmp_data.shape[0]
            tmp_data.sample(n = N, axis = 0, random_state=0).to_excel(writer,label, index = False)
    
    writer.save()

# %% [markdown]
# ### 之前算法判断为不相关

# %%
chunksize = 1000
day_select = '2018-07-25'

sql_1 = "SELECT count(0) \
                FROM wise_web_docinfo_uncorr t1 \
                where date_format(t1.publishtime, '%%Y-%%m-%%d') = '{0}'".format(day_select)
count = pd.read_sql_query(sql_1, engine)
loop = int(list(count.values)[0] / chunksize) + 1
loop
# Out:
# 96

# %%
sql_circ_uncor_one_day = "select t1.id, t1.publishtime,t1.title, t2.center as content \
                            from wise_web_docinfo_uncorr t1, wise_web_docinfo_center_uncurr t2 \
                                where t1.id = t2.doc_id \
                                  and date_format(t1.publishtime, '%%Y-%%m-%%d') = '{0}'".format(day_select) # 
# circ_uncor = pd.read_sql(sql_circ_uncor_one_day, engine)
# print(circ_uncor.shape)
# circ_uncor.head()

# %%
def get_time_diff(t1, t2):
    t = t2 - t1
    if t <= 60:
        return '%0.3f s'%t
    elif 60 < t <= 3600:
        t = t /60
        return '%0.3f min'%t
    else :
        t = t /3600
        return '%0.3f h'%t

# %%
i = 0
j = 0
loop_data = pd.DataFrame()
for tmp_data in pd.read_sql_query(sql_circ_uncor_one_day, engine, chunksize = chunksize):
    i += 1        
    print('--  共 %s次循环，第 %s 次获取数据，开始...'%(loop, i))        
    t1 = time.time()
    
    print('tmp_data: ', tmp_data.shape)
    data = {"record":tmp_data.loc[:,['id', 'title' ,'content']].to_dict(orient = 'records')}
    url = "http://192.168.0.104:11000/judge_correlation_i"
#     url = "http://47.93.77.19:10001/judge_correlation_i"
    parse_data, elapsed_time = get_server_res(data, url)
    print('elapsed_time: ', elapsed_time)
    parse_data.columns = ['id', 'predict_label']
    parse_data['predict_label'] = parse_data['predict_label'].apply(lambda x:class_name_dict[x])
    parse_data['label'] = ''
    combined_cor = pd.merge(parse_data, tmp_data, on = 'id', how = 'inner')    
    loop_data = pd.concat([loop_data, combined_cor], axis = 0)
    
    if loop % 10 == 0:
        j += 1
        print('---- loop_data: ', j)
        print(loop_data['predict_label'].value_counts())
        loop_data.drop(['titlehash', 'count'], 
                          axis = 1).to_excel('data/result/cor_predict_%s_%s.xlsx'%(day_select, 
                                                                                   loop), index = False)
        loop_data = pd.DataFrame()
    
    t2 = time.time()    
    print('--  共 %s次循环，第 %s 次获取数据%s，结束. 费时：%s'%(loop, i, 
                                                  loop_data.shape, 
                                                  get_time_diff(t1, t2)))
    print()
# Out:
# --  共 71次循环，第 1 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  77.00
# 噪音        947
# 资本市场       23
# 产品销售       10
# 监管          8
# 其他相关报道      7
# 消费服务        2
# 行业          2
# 公司内部管理      1
# Name: predict_label, dtype: int64
# --  共 71次循环，第 1 次获取数据(1000, 6)，结束. 费时：1.292 min
#
# --  共 71次循环，第 2 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  74.00
# 噪音        940
# 资本市场       30
# 监管         13
# 产品销售       10
# 其他相关报道      4
# 消费服务        2
# 行业          1
# Name: predict_label, dtype: int64
# --  共 71次循环，第 2 次获取数据(1000, 12)，结束. 费时：1.238 min
#
# --  共 71次循环，第 3 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  69.00
# 噪音        937
# 消费服务       19
# 资本市场       18
# 监管          8
# 产品销售        7
# 其他相关报道      7
# 公司内部管理      2
# 行业          2
# Name: predict_label, dtype: int64
# --  共 71次循环，第 3 次获取数据(1000, 18)，结束. 费时：1.155 min
#
# --  共 71次循环，第 4 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  75.00
# 噪音        954
# 资本市场       20
# 监管         14
# 产品销售        3
# 其他相关报道      3
# 消费服务        3
# 公司内部管理      3
# Name: predict_label, dtype: int64
# --  共 71次循环，第 4 次获取数据(1000, 24)，结束. 费时：1.262 min
#
# --  共 71次循环，第 5 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  77.00
# 噪音        930
# 资本市场       35
# 监管         20
# 其他相关报道      5
# 消费服务        4
# 行业          4
# 产品销售        2
# Name: predict_label, dtype: int64
# --  共 71次循环，第 5 次获取数据(1000, 30)，结束. 费时：1.292 min
#
# --  共 71次循环，第 6 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  73.00
# 噪音        923
# 资本市场       35
# 监管         17
# 产品销售        8
# 其他相关报道      7
# 消费服务        7
# 行业          3
# Name: predict_label, dtype: int64
# --  共 71次循环，第 6 次获取数据(1000, 36)，结束. 费时：1.225 min
#
# --  共 71次循环，第 7 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  83.00
# 噪音        918
# 资本市场       36
# 产品销售       17
# 监管         12
# 行业          6
# 消费服务        4
# 其他相关报道      4
# 公司内部管理      3
# Name: predict_label, dtype: int64
# --  共 71次循环，第 7 次获取数据(1000, 42)，结束. 费时：1.395 min
#
# --  共 71次循环，第 8 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  83.00
# 噪音        900
# 资本市场       54
# 监管         17
# 产品销售       10
# 其他相关报道      8
# 行业          5
# 公司内部管理      4
# 消费服务        2
# Name: predict_label, dtype: int64
# --  共 71次循环，第 8 次获取数据(1000, 48)，结束. 费时：1.398 min
#
# --  共 71次循环，第 9 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  70.00
# 噪音        917
# 资本市场       48
# 监管          9
# 行业          8
# 产品销售        6
# 消费服务        5
# 公司内部管理      4
# 其他相关报道      3
# Name: predict_label, dtype: int64
# --  共 71次循环，第 9 次获取数据(1000, 54)，结束. 费时：1.177 min
#
# --  共 71次循环，第 10 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  68.00
# 噪音        898
# 资本市场       57
# 监管         12
# 其他相关报道     10
# 产品销售        9
# 行业          6
# 消费服务        5
# 公司内部管理      3
# Name: predict_label, dtype: int64
# --  共 71次循环，第 10 次获取数据(1000, 60)，结束. 费时：1.145 min
#
# --  共 71次循环，第 11 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  67.00
# 噪音        865
# 资本市场       60
# 行业         30
# 其他相关报道     20
# 消费服务        8
# 产品销售        6
# 公司内部管理      6
# 监管          5
# Name: predict_label, dtype: int64
# --  共 71次循环，第 11 次获取数据(1000, 66)，结束. 费时：1.126 min
#
# --  共 71次循环，第 12 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  66.00
# 噪音        899
# 资本市场       57
# 消费服务       11
# 其他相关报道      9
# 行业          9
# 产品销售        6
# 监管          6
# 公司内部管理      3
# Name: predict_label, dtype: int64
# --  共 71次循环，第 12 次获取数据(1000, 72)，结束. 费时：1.103 min
#
# --  共 71次循环，第 13 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  69.00
# 噪音        909
# 资本市场       47
# 其他相关报道     11
# 产品销售        8
# 行业          8
# 监管          7
# 消费服务        7
# 公司内部管理      3
# Name: predict_label, dtype: int64
# --  共 71次循环，第 13 次获取数据(1000, 78)，结束. 费时：1.166 min
#
# --  共 71次循环，第 14 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  69.00
# 噪音        930
# 资本市场       38
# 其他相关报道     12
# 行业          6
# 监管          5
# 产品销售        4
# 公司内部管理      4
# 消费服务        1
# Name: predict_label, dtype: int64
# --  共 71次循环，第 14 次获取数据(1000, 84)，结束. 费时：1.159 min
#
# --  共 71次循环，第 15 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  63.00
# 噪音        904
# 资本市场       35
# 行业         19
# 其他相关报道     17
# 消费服务        9
# 产品销售        8
# 监管          4
# 公司内部管理      4
# Name: predict_label, dtype: int64
# --  共 71次循环，第 15 次获取数据(1000, 90)，结束. 费时：1.054 min
#
# --  共 71次循环，第 16 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  63.00
# 噪音        880
# 资本市场       60
# 行业         17
# 消费服务       15
# 产品销售       11
# 其他相关报道      8
# 公司内部管理      6
# 监管          3
# Name: predict_label, dtype: int64
# --  共 71次循环，第 16 次获取数据(1000, 96)，结束. 费时：1.058 min
#
# --  共 71次循环，第 17 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  63.00
# 噪音        913
# 资本市场       42
# 消费服务       10
# 行业         10
# 产品销售        9
# 监管          7
# 其他相关报道      7
# 公司内部管理      2
# Name: predict_label, dtype: int64
# --  共 71次循环，第 17 次获取数据(1000, 102)，结束. 费时：1.068 min
#
# --  共 71次循环，第 18 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  61.00
# 噪音        929
# 资本市场       41
# 其他相关报道     10
# 行业          8
# 消费服务        6
# 监管          4
# 产品销售        2
# Name: predict_label, dtype: int64
# --  共 71次循环，第 18 次获取数据(1000, 108)，结束. 费时：1.022 min
#
# --  共 71次循环，第 19 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  67.00
# 噪音        928
# 资本市场       42
# 其他相关报道      9
# 监管          5
# 消费服务        5
# 行业          5
# 产品销售        4
# 公司内部管理      2
# Name: predict_label, dtype: int64
# --  共 71次循环，第 19 次获取数据(1000, 114)，结束. 费时：1.134 min
#
# --  共 71次循环，第 20 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  65.00
# 噪音        918
# 资本市场       44
# 其他相关报道     12
# 行业          7
# 产品销售        6
# 监管          6
# 消费服务        4
# 公司内部管理      3
# Name: predict_label, dtype: int64
# --  共 71次循环，第 20 次获取数据(1000, 120)，结束. 费时：1.087 min
#
# --  共 71次循环，第 21 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  66.00
# 噪音        928
# 资本市场       40
# 其他相关报道     10
# 消费服务       10
# 产品销售        7
# 公司内部管理      3
# 监管          1
# 行业          1
# Name: predict_label, dtype: int64
# --  共 71次循环，第 21 次获取数据(1000, 126)，结束. 费时：1.106 min
#
# --  共 71次循环，第 22 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  78.00
# 噪音        910
# 资本市场       46
# 其他相关报道     11
# 行业         10
# 监管          9
# 消费服务        6
# 产品销售        4
# 公司内部管理      4
# Name: predict_label, dtype: int64
# --  共 71次循环，第 22 次获取数据(1000, 132)，结束. 费时：1.307 min
#
# --  共 71次循环，第 23 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  63.00
# 噪音        939
# 资本市场       32
# 监管          8
# 其他相关报道      6
# 产品销售        5
# 消费服务        4
# 公司内部管理      3
# 行业          3
# Name: predict_label, dtype: int64
# --  共 71次循环，第 23 次获取数据(1000, 138)，结束. 费时：1.057 min
#
# --  共 71次循环，第 24 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  63.00
# 噪音        941
# 资本市场       34
# 监管          5
# 消费服务        5
# 其他相关报道      5
# 公司内部管理      5
# 产品销售        3
# 行业          2
# Name: predict_label, dtype: int64
# --  共 71次循环，第 24 次获取数据(1000, 144)，结束. 费时：1.054 min
#
# --  共 71次循环，第 25 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  62.00
# 噪音        927
# 资本市场       25
# 其他相关报道     13
# 产品销售       10
# 监管         10
# 消费服务        6
# 行业          6
# 公司内部管理      3
# Name: predict_label, dtype: int64
# --  共 71次循环，第 25 次获取数据(1000, 150)，结束. 费时：1.045 min
#
# --  共 71次循环，第 26 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  59.00
# 噪音        903
# 资本市场       42
# 其他相关报道     17
# 消费服务       13
# 产品销售       12
# 行业          6
# 监管          4
# 公司内部管理      3
# Name: predict_label, dtype: int64
# --  共 71次循环，第 26 次获取数据(1000, 156)，结束. 费时：59.267 s
#
# --  共 71次循环，第 27 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  59.00
# 噪音        902
# 资本市场       28
# 其他相关报道     23
# 监管         16
# 消费服务       12
# 行业          9
# 产品销售        5
# 公司内部管理      5
# Name: predict_label, dtype: int64
# --  共 71次循环，第 27 次获取数据(1000, 162)，结束. 费时：59.981 s
#
# --  共 71次循环，第 28 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  60.00
# 噪音        897
# 资本市场       59
# 其他相关报道     16
# 监管          9
# 行业          7
# 公司内部管理      5
# 消费服务        4
# 产品销售        3
# Name: predict_label, dtype: int64
# --  共 71次循环，第 28 次获取数据(1000, 168)，结束. 费时：1.013 min
#
# --  共 71次循环，第 29 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  66.00
# 噪音        896
# 资本市场       42
# 其他相关报道     22
# 监管         14
# 消费服务        8
# 产品销售        7
# 行业          7
# 公司内部管理      4
# Name: predict_label, dtype: int64
# --  共 71次循环，第 29 次获取数据(1000, 174)，结束. 费时：1.105 min
#
# --  共 71次循环，第 30 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  59.00
# 噪音        928
# 资本市场       25
# 消费服务       14
# 监管         12
# 其他相关报道     10
# 产品销售        5
# 公司内部管理      4
# 行业          2
# Name: predict_label, dtype: int64
# --  共 71次循环，第 30 次获取数据(1000, 180)，结束. 费时：59.881 s
#
# --  共 71次循环，第 31 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  56.00
# 噪音        898
# 资本市场       42
# 产品销售       12
# 消费服务       12
# 行业         11
# 其他相关报道     10
# 监管          9
# 公司内部管理      6
# Name: predict_label, dtype: int64
# --  共 71次循环，第 31 次获取数据(1000, 186)，结束. 费时：57.117 s
#
# --  共 71次循环，第 32 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  76.00
# 噪音        916
# 资本市场       28
# 其他相关报道     18
# 公司内部管理     12
# 消费服务       10
# 产品销售        6
# 监管          5
# 行业          5
# Name: predict_label, dtype: int64
# --  共 71次循环，第 32 次获取数据(1000, 192)，结束. 费时：1.277 min
#
# --  共 71次循环，第 33 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  56.00
# 噪音        926
# 资本市场       33
# 其他相关报道     16
# 产品销售       12
# 监管          7
# 行业          5
# 公司内部管理      1
# Name: predict_label, dtype: int64
# --  共 71次循环，第 33 次获取数据(1000, 198)，结束. 费时：56.803 s
#
# --  共 71次循环，第 34 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  68.00
# 噪音        906
# 资本市场       45
# 其他相关报道     15
# 行业         13
# 消费服务        8
# 产品销售        6
# 公司内部管理      4
# 监管          3
# Name: predict_label, dtype: int64
# --  共 71次循环，第 34 次获取数据(1000, 204)，结束. 费时：1.150 min
#
# --  共 71次循环，第 35 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  63.00
# 噪音        947
# 资本市场       27
# 其他相关报道      9
# 消费服务        5
# 产品销售        4
# 监管          3
# 公司内部管理      3
# 行业          2
# Name: predict_label, dtype: int64
# --  共 71次循环，第 35 次获取数据(1000, 210)，结束. 费时：1.054 min
#
# --  共 71次循环，第 36 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  67.00
# 噪音        930
# 资本市场       38
# 其他相关报道     11
# 监管          6
# 消费服务        5
# 产品销售        4
# 行业          4
# 公司内部管理      2
# Name: predict_label, dtype: int64
# --  共 71次循环，第 36 次获取数据(1000, 216)，结束. 费时：1.135 min
#
# --  共 71次循环，第 37 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  74.00
# 噪音        937
# 资本市场       36
# 其他相关报道      7
# 产品销售        5
# 监管          5
# 消费服务        4
# 公司内部管理      3
# 行业          3
# Name: predict_label, dtype: int64
# --  共 71次循环，第 37 次获取数据(1000, 222)，结束. 费时：1.246 min
#
# --  共 71次循环，第 38 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  67.00
# 噪音        864
# 资本市场       49
# 其他相关报道     31
# 行业         21
# 监管         17
# 公司内部管理      7
# 消费服务        6
# 产品销售        5
# Name: predict_label, dtype: int64
# --  共 71次循环，第 38 次获取数据(1000, 228)，结束. 费时：1.122 min
#
# --  共 71次循环，第 39 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  66.00
# 噪音        918
# 资本市场       37
# 其他相关报道     13
# 监管          9
# 行业          9
# 产品销售        5
# 公司内部管理      5
# 消费服务        4
# Name: predict_label, dtype: int64
# --  共 71次循环，第 39 次获取数据(1000, 234)，结束. 费时：1.113 min
#
# --  共 71次循环，第 40 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  66.00
# 噪音        917
# 资本市场       37
# 其他相关报道     13
# 产品销售       10
# 监管          9
# 行业          7
# 消费服务        5
# 公司内部管理      2
# Name: predict_label, dtype: int64
# --  共 71次循环，第 40 次获取数据(1000, 240)，结束. 费时：1.114 min
#
# --  共 71次循环，第 41 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  70.00
# 噪音        936
# 资本市场       25
# 行业         10
# 消费服务        8
# 其他相关报道      8
# 产品销售        7
# 监管          4
# 公司内部管理      2
# Name: predict_label, dtype: int64
# --  共 71次循环，第 41 次获取数据(1000, 246)，结束. 费时：1.174 min
#
# --  共 71次循环，第 42 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  72.00
# 噪音        923
# 资本市场       39
# 其他相关报道     10
# 消费服务        7
# 行业          7
# 产品销售        6
# 公司内部管理      5
# 监管          3
# Name: predict_label, dtype: int64
# --  共 71次循环，第 42 次获取数据(1000, 252)，结束. 费时：1.210 min
#
# --  共 71次循环，第 43 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  65.00
# 噪音        917
# 资本市场       38
# 产品销售       15
# 公司内部管理      7
# 监管          6
# 消费服务        6
# 行业          6
# 其他相关报道      5
# Name: predict_label, dtype: int64
# --  共 71次循环，第 43 次获取数据(1000, 258)，结束. 费时：1.103 min
#
# --  共 71次循环，第 44 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  72.00
# 噪音        932
# 产品销售       20
# 资本市场       19
# 其他相关报道     10
# 行业          7
# 消费服务        6
# 公司内部管理      4
# 监管          2
# Name: predict_label, dtype: int64
# --  共 71次循环，第 44 次获取数据(1000, 264)，结束. 费时：1.207 min
#
# --  共 71次循环，第 45 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  67.00
# 噪音        907
# 资本市场       28
# 监管         20
# 产品销售       15
# 其他相关报道      9
# 消费服务        9
# 公司内部管理      9
# 行业          3
# Name: predict_label, dtype: int64
# --  共 71次循环，第 45 次获取数据(1000, 270)，结束. 费时：1.134 min
#
# --  共 71次循环，第 46 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  80.00
# 噪音        940
# 资本市场       26
# 监管          9
# 其他相关报道      9
# 消费服务        8
# 产品销售        7
# 公司内部管理      1
# Name: predict_label, dtype: int64
# --  共 71次循环，第 46 次获取数据(1000, 276)，结束. 费时：1.341 min
#
# --  共 71次循环，第 47 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  70.00
# 噪音        928
# 资本市场       48
# 其他相关报道      8
# 消费服务        6
# 公司内部管理      5
# 产品销售        2
# 监管          2
# 行业          1
# Name: predict_label, dtype: int64
# --  共 71次循环，第 47 次获取数据(1000, 282)，结束. 费时：1.184 min
#
# --  共 71次循环，第 48 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  66.00
# 噪音        844
# 资本市场      130
# 消费服务        8
# 监管          6
# 行业          5
# 公司内部管理      4
# 其他相关报道      2
# 产品销售        1
# Name: predict_label, dtype: int64
# --  共 71次循环，第 48 次获取数据(1000, 288)，结束. 费时：1.108 min
#
# --  共 71次循环，第 49 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  66.00
# 噪音        892
# 资本市场       65
# 产品销售       14
# 消费服务        9
# 监管          7
# 行业          7
# 其他相关报道      4
# 公司内部管理      2
# Name: predict_label, dtype: int64
# --  共 71次循环，第 49 次获取数据(1000, 294)，结束. 费时：1.115 min
#
# --  共 71次循环，第 50 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  71.00
# 噪音        860
# 资本市场       69
# 行业         19
# 产品销售       18
# 其他相关报道     17
# 消费服务       10
# 监管          5
# 公司内部管理      2
# Name: predict_label, dtype: int64
# --  共 71次循环，第 50 次获取数据(1000, 300)，结束. 费时：1.203 min
#
# --  共 71次循环，第 51 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  74.00
# 噪音        957
# 资本市场       26
# 其他相关报道      6
# 监管          5
# 行业          3
# 产品销售        1
# 消费服务        1
# 公司内部管理      1
# Name: predict_label, dtype: int64
# --  共 71次循环，第 51 次获取数据(1000, 306)，结束. 费时：1.239 min
#
# --  共 71次循环，第 52 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  82.00
# 噪音        903
# 产品销售       28
# 资本市场       21
# 其他相关报道     15
# 监管         14
# 行业         10
# 消费服务        6
# 公司内部管理      3
# Name: predict_label, dtype: int64
# --  共 71次循环，第 52 次获取数据(1000, 312)，结束. 费时：1.385 min
#
# --  共 71次循环，第 53 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  72.00
# 噪音        931
# 资本市场       26
# 产品销售       13
# 监管         11
# 其他相关报道      8
# 消费服务        6
# 行业          5
# Name: predict_label, dtype: int64
# --  共 71次循环，第 53 次获取数据(1000, 318)，结束. 费时：1.205 min
#
# --  共 71次循环，第 54 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  69.00
# 噪音        934
# 资本市场       35
# 消费服务        9
# 其他相关报道      8
# 产品销售        5
# 监管          5
# 行业          3
# 公司内部管理      1
# Name: predict_label, dtype: int64
# --  共 71次循环，第 54 次获取数据(1000, 324)，结束. 费时：1.158 min
#
# --  共 71次循环，第 55 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  70.00
# 噪音        916
# 资本市场       32
# 监管         23
# 其他相关报道     12
# 行业          6
# 消费服务        5
# 公司内部管理      4
# 产品销售        2
# Name: predict_label, dtype: int64
# --  共 71次循环，第 55 次获取数据(1000, 330)，结束. 费时：1.173 min
#
# --  共 71次循环，第 56 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  65.00
# 噪音        958
# 资本市场       12
# 产品销售        7
# 监管          6
# 消费服务        6
# 公司内部管理      5
# 其他相关报道      3
# 行业          3
# Name: predict_label, dtype: int64
# --  共 71次循环，第 56 次获取数据(1000, 336)，结束. 费时：1.102 min
#
# --  共 71次循环，第 57 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  71.00
# 噪音        943
# 资本市场       13
# 消费服务       11
# 产品销售        9
# 其他相关报道      7
# 监管          6
# 公司内部管理      6
# 行业          5
# Name: predict_label, dtype: int64
# --  共 71次循环，第 57 次获取数据(1000, 342)，结束. 费时：1.199 min
#
# --  共 71次循环，第 58 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  74.00
# 噪音        935
# 资本市场       19
# 其他相关报道     16
# 产品销售       15
# 监管          6
# 消费服务        6
# 公司内部管理      2
# 行业          1
# Name: predict_label, dtype: int64
# --  共 71次循环，第 58 次获取数据(1000, 348)，结束. 费时：1.238 min
#
# --  共 71次循环，第 59 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  76.00
# 噪音        923
# 产品销售       26
# 资本市场       21
# 消费服务       11
# 其他相关报道     10
# 公司内部管理      4
# 监管          3
# 行业          2
# Name: predict_label, dtype: int64
# --  共 71次循环，第 59 次获取数据(1000, 354)，结束. 费时：1.281 min
#
# --  共 71次循环，第 60 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  101.00
# 噪音        932
# 资本市场       20
# 产品销售       17
# 其他相关报道     11
# 行业          7
# 监管          6
# 消费服务        6
# 公司内部管理      1
# Name: predict_label, dtype: int64
# --  共 71次循环，第 60 次获取数据(1000, 360)，结束. 费时：1.691 min
#
# --  共 71次循环，第 61 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  121.00
# 噪音        899
# 产品销售       32
# 资本市场       22
# 其他相关报道     15
# 行业         11
# 监管         10
# 消费服务        8
# 公司内部管理      3
# Name: predict_label, dtype: int64
# --  共 71次循环，第 61 次获取数据(1000, 366)，结束. 费时：2.033 min
#
# --  共 71次循环，第 62 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  282.00
# 噪音        932
# 资本市场       21
# 消费服务       17
# 产品销售        9
# 其他相关报道      8
# 监管          7
# 公司内部管理      3
# 行业          3
# Name: predict_label, dtype: int64
# --  共 71次循环，第 62 次获取数据(1000, 372)，结束. 费时：4.721 min
#
# --  共 71次循环，第 63 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  137.00
# 噪音        908
# 资本市场       27
# 其他相关报道     17
# 产品销售       14
# 消费服务       12
# 行业         11
# 监管          9
# 公司内部管理      2
# Name: predict_label, dtype: int64
# --  共 71次循环，第 63 次获取数据(1000, 378)，结束. 费时：2.304 min
#
# --  共 71次循环，第 64 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  174.00
# 噪音        941
# 资本市场       33
# 消费服务        6
# 行业          6
# 产品销售        4
# 监管          4
# 其他相关报道      4
# 公司内部管理      2
# Name: predict_label, dtype: int64
# --  共 71次循环，第 64 次获取数据(1000, 384)，结束. 费时：2.916 min
#
# --  共 71次循环，第 65 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  118.00
# 噪音        929
# 资本市场       31
# 产品销售       10
# 监管          9
# 其他相关报道      9
# 行业          6
# 消费服务        3
# 公司内部管理      3
# Name: predict_label, dtype: int64
# --  共 71次循环，第 65 次获取数据(1000, 390)，结束. 费时：1.987 min
#
# --  共 71次循环，第 66 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  108.00
# 噪音        933
# 资本市场       26
# 其他相关报道     10
# 行业         10
# 公司内部管理      6
# 产品销售        5
# 监管          5
# 消费服务        5
# Name: predict_label, dtype: int64
# --  共 71次循环，第 66 次获取数据(1000, 396)，结束. 费时：1.817 min
#
# --  共 71次循环，第 67 次获取数据，开始...
# tmp_data:  (1000, 4)
# elapsed_time:  112.00
# 噪音        964
# 资本市场       13
# 其他相关报道      7
# 行业          6
# 产品销售        4
# 消费服务        4
# 监管          2
# Name: predict_label, dtype: int64
# --  共 71次循环，第 67 次获取数据(1000, 402)，结束. 费时：1.884 min
#
# --  共 71次循环，第 68 次获取数据，开始...
# tmp_data:  (948, 4)
# elapsed_time:  108.00
# 噪音        875
# 资本市场       20
# 产品销售       16
# 其他相关报道     16
# 监管          9
# 行业          5
# 消费服务        4
# 公司内部管理      3
# Name: predict_label, dtype: int64
# --  共 71次循环，第 68 次获取数据(1000, 408)，结束. 费时：1.817 min
# 2018-08-08 22:30:54  pool.py[line:696]  ERROR Exception during reset or similar
# Traceback (most recent call last):
#   File "D:\software\conda\lib\site-packages\pymysql\connections.py", line 1021, in _read_bytes
#     data = self._rfile.read(num_bytes)
#   File "D:\software\conda\lib\socket.py", line 586, in readinto
#     return self._sock.recv_into(b)
# TimeoutError: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\software\conda\lib\site-packages\sqlalchemy\pool.py", line 687, in _finalize_fairy
#     fairy._reset(pool)
#   File "D:\software\conda\lib\site-packages\sqlalchemy\pool.py", line 829, in _reset
#     pool._dialect.do_rollback(self)
#   File "D:\software\conda\lib\site-packages\sqlalchemy\dialects\mysql\base.py", line 1575, in do_rollback
#     dbapi_connection.rollback()
#   File "D:\software\conda\lib\site-packages\pymysql\connections.py", line 793, in rollback
#     self._read_ok_packet()
#   File "D:\software\conda\lib\site-packages\pymysql\connections.py", line 767, in _read_ok_packet
#     pkt = self._read_packet()
#   File "D:\software\conda\lib\site-packages\pymysql\connections.py", line 987, in _read_packet
#     packet_header = self._read_bytes(4)
#   File "D:\software\conda\lib\site-packages\pymysql\connections.py", line 1029, in _read_bytes
#     "Lost connection to MySQL server during query (%s)" % (e,))
# pymysql.err.OperationalError: (2013, 'Lost connection to MySQL server during query ([WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。)')

# %%
for day_select in day_list:
    print('-- day_select: ', day_select)
    sql_circ_uncor_one_day = "select t1.id, t1.publishtime,t1.title, t2.center as content \
                                from wise_web_docinfo_uncorr t1, wise_web_docinfo_center_uncurr t2 \
                                    where t1.id = t2.doc_id \
                                      and date_format(t1.publishtime, '%%Y-%%m-%%d') = '{0}'".format(day_select) # 
    
    i = 0
    loop_data = pd.DataFrame()
    for tmp_data in pd.read_sql_query(sql_circ_uncor_one_day, engine, chunksize = chunksize):
        i += 1        
        print('--  共 %s次循环，第 %s 次获取数据，开始...'%(loop, i))        
        t1 = time.time()

        print('tmp_data: ', tmp_data.shape)
        data = {"record":tmp_data.loc[:,['id', 'title' ,'content']].to_dict(orient = 'records')}
        url = "http://192.168.0.104:11000/judge_correlation_i"
    #     url = "http://47.93.77.19:10001/judge_correlation_i"
        parse_data, elapsed_time = get_server_res(data, url)
        print('elapsed_time: ', elapsed_time)
        parse_data.columns = ['id', 'predict_label']
        parse_data['predict_label'] = parse_data['predict_label'].apply(lambda x:class_name_dict[x])
        parse_data['label'] = ''
        combined_cor = pd.merge(parse_data, tmp_data, on = 'id', how = 'inner')
        print(combined_cor['predict_label'].value_counts())
        loop_data = pd.concat([loop_data, combined_cor], axis = 1)

        if loop % 10 == 0:
            loop_data.drop(['titlehash', 'count'], 
                              axis = 1).to_excel('data/result/cor_predict_%s_%s.xlsx'%(day_select, 
                                                                                       loop), index = False)
            loop_data = pd.DataFrame()

        t2 = time.time()    
        print('--  共 %s次循环，第 %s 次获取数据%s，结束. 费时：%s'%(loop, i, 
                                                      loop_data.shape, 
                                                      get_time_diff(t1, t2)))
        print()

# %% [markdown]
# ## 测试模型：本地服务

# %%
i = 0
for tmp_data in pd.read_sql_query(sql_circ_uncor_one_day, engine, chunksize = chunksize):
    i += 1        
    print('--  一、共 %s次循环，第 %s 次获取数据，开始...'%(loop, i))
    
    try :
        # 本地模型
        data = {"record":tmp_data.loc[:,['id', 'title' ,'content']].to_dict(orient = 'records')}
        url = "http://192.168.0.104:11000/correlation_negative"
        parse_data = get_server_res(data, url)
        res = parse_data['sec'].tolist()
        res_2 = float(sum(res))/len(res)    

    except Exception as e:
        print('error message: ', e)
        print('-------------------')
        continue

# %%
day_select = '2018-06-01'
additional = additional.sort_values(by='publishtime')

fig = plt.figure(figsize = (15,6))
ax1 = fig.add_subplot(111)
additional[additional['publishtime'] > day_select]['file_num'].plot(x = 'publishtime',kind = 'bar', ax = ax1, alpha = 0.3)
ax1.set_ylabel('文件数量', fontsize = 16)
ax1.set_xlabel('publishtime', fontsize = 16)
ax1.set_ylim(0, num * 10)

ax2 = ax1.twinx()  # this is the important function
additional[additional['publishtime'] > day_select].plot(x = 'publishtime', 
                                                        y = [ 'online_model', 'local_model'] + model_list,
                                        ax = ax2, kind = 'line', marker = 'D') 
ax2.set_title("不同模型判断-随机-算法相关", fontsize = 20)
ax2.set_ylabel('随机-算法相关-识别率', fontsize = 16)
ax2.grid(linestyle="--", alpha=0.3) 
ax2.set_ylim(0, 1)
plt.savefig('fig/%s_保监会_不同模型判断-随机-算法相关.png'%today_str, format='png')

additional.sort_values(by='publishtime', ascending = False).head()
# Out:
#    publishtime  file_num  online_model  local_model  circ_cor_0703  \
# 16  2018-07-03       100          1.00         0.78           0.52
# 15  2018-07-02       100          1.00         0.80           0.55
# 14  2018-07-01       100          0.97         0.59           0.40
# 13  2018-06-30       100          1.00         0.70           0.49
# 12  2018-06-29       100          0.99         0.77           0.59
#
#     0619_circ_cor_noise  circ_cor_0625  circ_cor_0623
# 16                 0.49           0.64           0.67
# 15                 0.51           0.68           0.72
# 14                 0.38           0.67           0.66
# 13                 0.37           0.57           0.55
# 12                 0.60           0.73           0.72

# %% [markdown]
# # 补录数据

# %% [markdown]
# ## 获取数据

# %%
DB_CON_STR = 'mysql+pymysql://wisedb:Wi$eWeb123@47.95.148.133:5718/pom?charset=utf8'  
engine = create_engine(DB_CON_STR, echo=False)

# %%
import datetime

today = datetime.datetime.now()
today_str = today.strftime("%Y-%m-%d")
yesterday = today - datetime.timedelta(days=1)
yesterday_str = yesterday.strftime("%Y-%m-%d")

start_day = '2018-08-10'  # 含
end_day = yesterday_str    # 含
print(end_day)
# Out:
# 2018-08-15

# %%
label_dic={'补录':0,'监管':1,'行业':2,'产品销售':3,'资本市场':4,'公司内部管理':5,'消费服务':6,'其他相关报道':7,'噪音':8}
class_name_dict = {v: k for k, v in label_dic.items()}
class_name_dict
# Out:
# {0: '补录',
#  1: '监管',
#  2: '行业',
#  3: '产品销售',
#  4: '资本市场',
#  5: '公司内部管理',
#  6: '消费服务',
#  7: '其他相关报道',
#  8: '噪音'}

# %%
# 相关数据
sql_circ_cor = "select date_format(t1.publishtime,'%%Y-%%m-%%d') as publishtime, t1.classify, \
                            count(t1.id) as count \
                            from wise_web_docinfo t1 \
                                where (date_format(publishtime, '%%Y-%%m-%%d') >= '{0}' and \
                                      date_format(publishtime, '%%Y-%%m-%%d') <= '{1}') \
                                group by date_format(t1.publishtime,'%%Y-%%m-%%d'), t1.classify \
                                order by date_format(t1.publishtime,'%%Y-%%m-%%d') desc".format(start_day, end_day) 

circ_cor_count = pd.read_sql(sql_circ_cor, engine)
circ_cor_count['classify'] = circ_cor_count['classify'].apply(lambda x:class_name_dict[x])
# circ_cor_count['cor'] = '相关'
circ_cor_count.iloc[:5,:]
# Out:
#   publishtime classify  count
# 0  2018-08-15       补录     40
# 1  2018-08-15       监管    936
# 2  2018-08-15       行业    502
# 3  2018-08-15   公司内部管理    414
# 4  2018-08-15     消费服务    236

# %%
# 不相关数据
sql_circ_uncor = "select date_format(t1.publishtime,'%%Y-%%m-%%d') as publishtime,t1.classify, count(t1.id) as count \
                            from wise_web_docinfo_uncorr t1 \
                                where (date_format(t1.publishtime, '%%Y-%%m-%%d') >= '{0}' and \
                                      date_format(t1.publishtime, '%%Y-%%m-%%d') <= '{1}') \
                                group by t1.classify, date_format(t1.publishtime,'%%Y-%%m-%%d') \
                                order by date_format(t1.publishtime,'%%Y-%%m-%%d') desc".format(start_day, end_day) 

circ_uncor_count = pd.read_sql(sql_circ_uncor, engine)
circ_uncor_count['classify'] = circ_uncor_count['classify'].apply(lambda x:class_name_dict[x])
# circ_uncor_count['cor'] = '不相关'
circ_uncor_count.iloc[:5,:]
# Out:
#   publishtime classify  count
# 0  2018-08-15   其他相关报道    579
# 1  2018-08-15       噪音  15800
# 2  2018-08-15     产品销售    624
# 3  2018-08-15     资本市场   1820
# 4  2018-08-14     资本市场   1480

# %% [markdown]
# ## 补录图表

# %%
# 补录
apend = circ_cor_count[circ_cor_count['classify'] == '补录'][['publishtime', 'count']]
apend.columns = ['publishtime', '补录']
apend.plot(kind = 'bar', x = 'publishtime', y = '补录', figsize=(15,6), 
           title = '补录数据-每天', grid = True)
apend
# Out:
#    publishtime  补录
# 0   2018-08-15  40
# 5   2018-08-14  36
# 10  2018-08-13  34
# 15  2018-08-12  11
# 20  2018-08-11   9
# 25  2018-08-10  36

# %% [markdown]
# ## 相关-不相关 图表

# %%
cor_count = circ_cor_count[circ_cor_count['classify'] != '补录'].groupby(['publishtime'])['count'].sum().reset_index()
cor_count.columns = ['publishtime', '算法-相关']
uncor_count = circ_uncor_count.groupby(['publishtime'])['count'].sum().reset_index()
uncor_count.columns = ['publishtime', '算法-不相关']
count_data = pd.merge(cor_count, uncor_count, on = 'publishtime')
count_data['算法-相关性'] = count_data['算法-相关'] + count_data['算法-不相关']
count_data['算法-相关-比例'] = count_data['算法-相关'] / count_data['算法-相关性']
count_data['算法-不相关-比例'] = count_data['算法-不相关'] / count_data['算法-相关性']
count_data.sort_values(by = 'publishtime', ascending = False).head()
# Out:
#   publishtime  算法-相关  算法-不相关  算法-相关性  算法-相关-比例  算法-不相关-比例
# 5  2018-08-15   2088   18823   20911  0.099852   0.900148
# 4  2018-08-14   2575   25284   27859  0.092430   0.907570
# 3  2018-08-13   6181   41590   47771  0.129388   0.870612
# 2  2018-08-12   3120   37462   40582  0.076881   0.923119
# 1  2018-08-11   3560   46370   49930  0.071300   0.928700

# %%
fig = plt.figure(figsize = (15,6))
ax1 = fig.add_subplot(111)
rects = count_data[['算法-相关', '算法-不相关']].plot(kind = 'bar', ax = ax1, alpha=0.5, stacked=True)
ax1.set_ylabel('数据量', fontsize = 16)
ax1.set_title("（保监会）八分类模型：相关 - 不相关", fontsize = 20)
ax1.legend(['算法-相关', '算法-不相关'], loc='upper left')

ax2 = ax1.twinx()  # this is the important function
count_data[['算法-相关-比例', '算法-不相关-比例']].plot(x = count_data['publishtime'],
                                          kind = 'line', ax = ax2, marker = 'D')
ax2.set_ylabel('比例', fontsize = 16)
ax2.set_xlabel('publishtime', fontsize = 16)
ax2.set_ylim(0, 1)
ax2.legend(['算法-相关-比例', '算法-不相关-比例'], loc='upper center')
        
plt.grid(True, linestyle = "--", color = "r", alpha = 0.3) 
plt.show()

# %% [markdown]
# ## 类别 图表

# %%
class_count = pd.concat([circ_cor_count, circ_uncor_count])

cor_class = class_count.set_index(['publishtime', 'classify']).unstack()#.reset_index('publishtime')
cor_class['总量'] = cor_class['count'].sum(axis = 1)
cor_class
# Out:
#             count                                                    总量
# classify     产品销售 公司内部管理 其他相关报道     噪音 消费服务    监管   行业  补录  资本市场
# publishtime
# 2018-08-10    869    676    686  65510  308  4335  645  36  3473  76538
# 2018-08-11    639    135    265  44566   97  3134  194   9   900  49939
# 2018-08-12    534    140    188  35769   72  2652  256  11   971  40593
# 2018-08-13    758    511    517  37471  310  4668  692  34  2844  47805
# 2018-08-14    677    391    428  22699  260  1476  448  36  1480  27895
# 2018-08-15    624    414    579  15800  236   936  502  40  1820  20951

# %%
for k in list(label_dic.keys()):
    cor_class['rate', k] = cor_class['count', k] / cor_class['总量']
cor_class
# Out:
#             count                                                    总量  \
# classify     产品销售 公司内部管理 其他相关报道     噪音 消费服务    监管   行业  补录  资本市场
# publishtime
# 2018-08-10    869    676    686  65510  308  4335  645  36  3473  76538
# 2018-08-11    639    135    265  44566   97  3134  194   9   900  49939
# 2018-08-12    534    140    188  35769   72  2652  256  11   971  40593
# 2018-08-13    758    511    517  37471  310  4668  692  34  2844  47805
# 2018-08-14    677    391    428  22699  260  1476  448  36  1480  27895
# 2018-08-15    624    414    579  15800  236   936  502  40  1820  20951
#
#                  rate                                                    \
# classify           补录        监管        行业      产品销售      资本市场    公司内部管理
# publishtime
# 2018-08-10   0.000470  0.056639  0.008427  0.011354  0.045376  0.008832
# 2018-08-11   0.000180  0.062757  0.003885  0.012796  0.018022  0.002703
# 2018-08-12   0.000271  0.065331  0.006307  0.013155  0.023920  0.003449
# 2018-08-13   0.000711  0.097647  0.014475  0.015856  0.059492  0.010689
# 2018-08-14   0.001291  0.052913  0.016060  0.024270  0.053056  0.014017
# 2018-08-15   0.001909  0.044676  0.023961  0.029784  0.086869  0.019760
#
#
# classify         消费服务    其他相关报道        噪音
# publishtime
# 2018-08-10   0.004024  0.008963  0.855915
# 2018-08-11   0.001942  0.005306  0.892409
# 2018-08-12   0.001774  0.004631  0.881162
# 2018-08-13   0.006485  0.010815  0.783830
# 2018-08-14   0.009321  0.015343  0.813730
# 2018-08-15   0.011264  0.027636  0.754141

# %%
import seaborn as sns

f, ax=plt.subplots(figsize=(15,6))
sns.barplot(x="publishtime", y="count", hue="classify", data=class_count)
plt.title('（保监会）细分来源', fontsize = 20)
plt.show()

# %% [markdown]
# # 保存本文件

# %%
if 0:
    import datetime as dt
    
    def output_HTML(read_file, output_file):
        from nbconvert import HTMLExporter
        import codecs
        import nbformat
        exporter = HTMLExporter()
        # read_file is '.ipynb', output_file is '.html'
        output_notebook = nbformat.read(read_file, as_version=4)
        output, resources = exporter.from_notebook_node(output_notebook)
        codecs.open(output_file, 'w', encoding='utf-8').write(output)

    html_file_folder = 'html_files'
    if not os.path.exists(html_file_folder):
        os.makedirs(html_file_folder)

    today = dt.datetime.now().strftime('%Y%m%d')
    current_file = 'circ_cor_model_3_test.ipynb'
    output_file = 'html_files\%s_%s.html'%(os.path.splitext(current_file)[0], today)
    output_HTML(current_file, output_file)
