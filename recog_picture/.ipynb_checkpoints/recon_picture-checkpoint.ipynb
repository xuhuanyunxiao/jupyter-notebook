# %% [markdown]
# # 本文件说明
# - 图片识别

# %% [markdown]
# # 基本设置

# %%
import os
import base64
import hashlib  
import time  
import random  
import string  
from urllib.parse import quote  
import requests

# %%
def curlmd5(src):  
    m = hashlib.md5(src.encode('UTF-8'))
    return m.hexdigest().upper()
 
# 请求时间戳（秒级），用于防止请求重放（保证签名5分钟有效） 
def get_params(base64_data):
    t = time.time()
    time_stamp=str(int(t))  
    # 请求随机字符串，用于保证签名不可预测  
    nonce_str = ''.join(random.sample(string.ascii_letters + string.digits, 10))  
    #print(nonce_str)
    # 应用标志，这里修改成自己的id和key  
    app_id = '2107878067'  
    app_key = '1GhxSLrCfQydpL81'
    params = {'app_id':app_id,  
              'image':base64_data,
              'time_stamp':time_stamp,
              'nonce_str':nonce_str,
              #'format':'1',
              #'topk':'5',
             }
    sign_before = ''
    # 要对key排序再拼接
    for key in sorted(params):
        # 键值拼接过程value部分需要URL编码，URL编码算法用大写字母，例如%E8。quote默认大写。  
        sign_before += '{}={}&'.format(key,quote(params[key], safe=''))
        #print(quote(params[key], safe=''))
    # 将应用密钥以app_key为键名，拼接到字符串sign_before末尾  
    sign_before += 'app_key={}'.format(app_key)
    # 对字符串sign_before进行MD5运算，得到接口请求签名
    #print(sign_before)
    sign = curlmd5(sign_before)
    params['sign'] = sign
    #print(sign)
    #print(params)
    return params

# %% [markdown]
# # 识别图片

# %%
name_list = os.listdir('data/')
name_list
# Out:
# ['河南_APP.png', '河南_公众号.png', '河南_网站.png']

# %%
url = "https://api.ai.qq.com/fcgi-bin/ocr/ocr_generalocr"
#url = "https://api.ai.qq.com/fcgi-bin/vision/vision_objectr"

res = []

for name in name_list:
    with open('data/{0}'.format(name),'rb') as fin:
        image_data = fin.read()
    base64_data = base64.b64encode(image_data)
    params = get_params(base64_data)
    #print(params)
    r = requests.post(url,data=params)
    item_list = r.json()['data']['item_list']
    #print(r.json())

    for index, s in enumerate(item_list):
        if (index+1) % 3:
#             print(s['itemstring'])
# Out:
# 序号
# 服务名称
# 单位名称
# 许可证编号
# 1
# “大河网”
# 大河网络传媒集团有限公司
# 41120170001
# 2
# “眼遇”
# 大河网络传媒集团有限公司
# 41120170001
# 3
# “掌上洛阳”
# 洛阳日报社
# 41120170003
# 4
# “汴梁风”
# 开封日报社
# 41120170004
# 5
# “掌上开封”
# 开封日报社
# 41120170004
# 6
# “映象新闻客户端”
# 河南广播电视台
# 41120170005
# 序号
# 服务名称
# 单位名称
# 许可证编号
# “大河网”，腾讯微信
# 大河网络传媒集团有限公司
# 41120170001
# 公众账号。
# “大河网”,新浪微博
# 大河网络传媒集团有限公司
# 41120170001
# 公众账号。
# “中原网”，腾讯微信
# 郑州报业集团
# 41120170002
# 公众账号。
# “中原网”,新浪微博
# 郑州报业集团
# 41120170002
# 公众账号。
# “洛阳网”，腾讯微信
# 洛阳日报社
# 41120170003
# 公众账号。
# “洛阳网”，新浪微博
# 洛阳日报社
# 41120170003
# 公众账号。
# “开封网”，腾讯微信
# 开封日报社
# 41120170004
# 公众账号。
# 8
# “开封网”，新浪微博
# 开封日报社
# 41120170004
# 公众账号。
# 9
# “映象网”，腾讯微信
# 河南广播电视台
# 41120170005
# 公众账号。
# 10
# “映象网”，新浪微博
# 河南广播电视台
# 41120170005
# 公众账号。
# 序号
# 服务名称
# 服务地址
# 许可证编号
# 1
# 大河网
# www. dahe. cn
# 41120170001
# wwwww wwwwwwww. www
# 2
# 中原网
# www. zvnews. cn
# 41120170002
# 3
# 洛阳网
# www. lvd. com. cn
# 41120170003
# 4
# 开封网
# www. kf. cn
# 41120170004
# wwww. w ww
# 5
# 映象网
# www. hnr. cn
# 41120170005

# %%
item_list
# Out:
# [{'item': '',
#   'itemcoord': [{'height': 22, 'width': 40, 'x': 45, 'y': 20}],
#   'itemstring': '序号',
#   'words': [{'character': '序', 'confidence': 0.999915},
#    {'character': '号', 'confidence': 0.999577}]},
#  {'item': '',
#   'itemcoord': [{'height': 21, 'width': 81, 'x': 152, 'y': 20}],
#   'itemstring': '服务名称',
#   'words': [{'character': '服', 'confidence': 0.999998},
#    {'character': '务', 'confidence': 0.999998},
#    {'character': '名', 'confidence': 0.999967},
#    {'character': '称', 'confidence': 0.999986}]},
#  {'item': '',
#   'itemcoord': [{'height': 21, 'width': 81, 'x': 316, 'y': 20}],
#   'itemstring': '服务地址',
#   'words': [{'character': '服', 'confidence': 0.999997},
#    {'character': '务', 'confidence': 0.999999},
#    {'character': '地', 'confidence': 0.999953},
#    {'character': '址', 'confidence': 0.999996}]},
#  {'item': '',
#   'itemcoord': [{'height': 21, 'width': 99, 'x': 484, 'y': 20}],
#   'itemstring': '许可证编号',
#   'words': [{'character': '许', 'confidence': 0.999988},
#    {'character': '可', 'confidence': 0.999997},
#    {'character': '证', 'confidence': 0.999984},
#    {'character': '编', 'confidence': 0.999972},
#    {'character': '号', 'confidence': 0.999957}]},
#  {'item': '',
#   'itemcoord': [{'height': 16, 'width': 14, 'x': 59, 'y': 71}],
#   'itemstring': '1',
#   'words': [{'character': '1', 'confidence': 0.979935}]},
#  {'item': '',
#   'itemcoord': [{'height': 21, 'width': 60, 'x': 161, 'y': 69}],
#   'itemstring': '大河网',
#   'words': [{'character': '大', 'confidence': 0.978984},
#    {'character': '河', 'confidence': 0.999937},
#    {'character': '网', 'confidence': 0.99997}]},
#  {'item': '',
#   'itemcoord': [{'height': 19, 'width': 112, 'x': 299, 'y': 71}],
#   'itemstring': 'www. dahe. cn',
#   'words': [{'character': 'w', 'confidence': 0.989967},
#    {'character': 'w', 'confidence': 0.981343},
#    {'character': 'w', 'confidence': 0.983651},
#    {'character': '.', 'confidence': 0.996156},
#    {'character': '', 'confidence': 1},
#    {'character': 'd', 'confidence': 0.59496},
#    {'character': 'a', 'confidence': 0.999753},
#    {'character': 'h', 'confidence': 0.999082},
#    {'character': 'e', 'confidence': 0.999903},
#    {'character': '.', 'confidence': 0.998757},
#    {'character': '', 'confidence': 1},
#    {'character': 'c', 'confidence': 0.959893},
#    {'character': 'n', 'confidence': 0.996691}]},
#  {'item': '',
#   'itemcoord': [{'height': 16, 'width': 108, 'x': 479, 'y': 71}],
#   'itemstring': '41120170001',
#   'words': [{'character': '4', 'confidence': 0.999704},
#    {'character': '1', 'confidence': 0.998414},
#    {'character': '1', 'confidence': 0.99791},
#    {'character': '2', 'confidence': 0.996092},
#    {'character': '0', 'confidence': 0.999664},
#    {'character': '1', 'confidence': 0.998865},
#    {'character': '7', 'confidence': 0.998938},
#    {'character': '0', 'confidence': 0.998876},
#    {'character': '0', 'confidence': 0.999348},
#    {'character': '0', 'confidence': 0.999106},
#    {'character': '1', 'confidence': 0.992728}]},
#  {'item': '',
#   'itemcoord': [{'height': 6, 'width': 112, 'x': 298, 'y': 87}],
#   'itemstring': 'wwwww wwwwwwww. www',
#   'words': [{'character': 'w', 'confidence': 0.810494},
#    {'character': 'w', 'confidence': 0.787718},
#    {'character': 'w', 'confidence': 0.7231},
#    {'character': 'w', 'confidence': 0.524843},
#    {'character': 'w', 'confidence': 0.623402},
#    {'character': '', 'confidence': 1},
#    {'character': 'w', 'confidence': 0.459959},
#    {'character': 'w', 'confidence': 0.478709},
#    {'character': 'w', 'confidence': 0.829239},
#    {'character': 'w', 'confidence': 0.880595},
#    {'character': 'w', 'confidence': 0.783172},
#    {'character': 'w', 'confidence': 0.586965},
#    {'character': 'w', 'confidence': 0.714814},
#    {'character': 'w', 'confidence': 0.760051},
#    {'character': '.', 'confidence': 0.572302},
#    {'character': '', 'confidence': 1},
#    {'character': 'w', 'confidence': 0.658257},
#    {'character': 'w', 'confidence': 0.805407},
#    {'character': 'w', 'confidence': 0.81875}]},
#  {'item': '',
#   'itemcoord': [{'height': 15, 'width': 9, 'x': 64, 'y': 124}],
#   'itemstring': '2',
#   'words': [{'character': '2', 'confidence': 0.996745}]},
#  {'item': '',
#   'itemcoord': [{'height': 19, 'width': 58, 'x': 163, 'y': 122}],
#   'itemstring': '中原网',
#   'words': [{'character': '中', 'confidence': 0.999788},
#    {'character': '原', 'confidence': 0.999988},
#    {'character': '网', 'confidence': 0.99999}]},
#  {'item': '',
#   'itemcoord': [{'height': 13, 'width': 129, 'x': 291, 'y': 127}],
#   'itemstring': 'www. zvnews. cn',
#   'words': [{'character': 'w', 'confidence': 0.866632},
#    {'character': 'w', 'confidence': 0.873347},
#    {'character': 'w', 'confidence': 0.91201},
#    {'character': '.', 'confidence': 0.999507},
#    {'character': '', 'confidence': 1},
#    {'character': 'z', 'confidence': 0.975801},
#    {'character': 'v', 'confidence': 0.885752},
#    {'character': 'n', 'confidence': 0.99709},
#    {'character': 'e', 'confidence': 0.999441},
#    {'character': 'w', 'confidence': 0.99699},
#    {'character': 's', 'confidence': 0.966356},
#    {'character': '.', 'confidence': 0.991461},
#    {'character': '', 'confidence': 1},
#    {'character': 'c', 'confidence': 0.955104},
#    {'character': 'n', 'confidence': 0.992676}]},
#  {'item': '',
#   'itemcoord': [{'height': 17, 'width': 107, 'x': 480, 'y': 123}],
#   'itemstring': '41120170002',
#   'words': [{'character': '4', 'confidence': 0.999911},
#    {'character': '1', 'confidence': 0.99804},
#    {'character': '1', 'confidence': 0.99924},
#    {'character': '2', 'confidence': 0.999923},
#    {'character': '0', 'confidence': 0.999945},
#    {'character': '1', 'confidence': 0.999977},
#    {'character': '7', 'confidence': 0.999981},
#    {'character': '0', 'confidence': 0.999847},
#    {'character': '0', 'confidence': 0.99988},
#    {'character': '0', 'confidence': 0.999882},
#    {'character': '2', 'confidence': 0.999977}]},
#  {'item': '',
#   'itemcoord': [{'height': 14, 'width': 10, 'x': 63, 'y': 176}],
#   'itemstring': '3',
#   'words': [{'character': '3', 'confidence': 0.995444}]},
#  {'item': '',
#   'itemcoord': [{'height': 20, 'width': 60, 'x': 161, 'y': 173}],
#   'itemstring': '洛阳网',
#   'words': [{'character': '洛', 'confidence': 0.997576},
#    {'character': '阳', 'confidence': 0.999965},
#    {'character': '网', 'confidence': 0.999919}]},
#  {'item': '',
#   'itemcoord': [{'height': 16, 'width': 139, 'x': 286, 'y': 177}],
#   'itemstring': 'www. lvd. com. cn',
#   'words': [{'character': 'w', 'confidence': 0.996436},
#    {'character': 'w', 'confidence': 0.994283},
#    {'character': 'w', 'confidence': 0.98875},
#    {'character': '.', 'confidence': 0.436414},
#    {'character': '', 'confidence': 1},
#    {'character': 'l', 'confidence': 0.886062},
#    {'character': 'v', 'confidence': 0.721289},
#    {'character': 'd', 'confidence': 0.996755},
#    {'character': '.', 'confidence': 0.830798},
#    {'character': '', 'confidence': 1},
#    {'character': 'c', 'confidence': 0.992827},
#    {'character': 'o', 'confidence': 0.988473},
#    {'character': 'm', 'confidence': 0.996601},
#    {'character': '.', 'confidence': 0.997254},
#    {'character': '', 'confidence': 1},
#    {'character': 'c', 'confidence': 0.964995},
#    {'character': 'n', 'confidence': 0.992198}]},
#  {'item': '',
#   'itemcoord': [{'height': 17, 'width': 109, 'x': 479, 'y': 175}],
#   'itemstring': '41120170003',
#   'words': [{'character': '4', 'confidence': 0.999788},
#    {'character': '1', 'confidence': 0.999513},
#    {'character': '1', 'confidence': 0.99846},
#    {'character': '2', 'confidence': 0.998179},
#    {'character': '0', 'confidence': 0.999789},
#    {'character': '1', 'confidence': 0.999769},
#    {'character': '7', 'confidence': 0.998715},
#    {'character': '0', 'confidence': 0.999842},
#    {'character': '0', 'confidence': 0.999886},
#    {'character': '0', 'confidence': 0.999894},
#    {'character': '3', 'confidence': 0.999777}]},
#  {'item': '',
#   'itemcoord': [{'height': 16, 'width': 9, 'x': 64, 'y': 222}],
#   'itemstring': '4',
#   'words': [{'character': '4', 'confidence': 0.997574}]},
#  {'item': '',
#   'itemcoord': [{'height': 21, 'width': 60, 'x': 161, 'y': 220}],
#   'itemstring': '开封网',
#   'words': [{'character': '开', 'confidence': 0.99994},
#    {'character': '封', 'confidence': 0.999964},
#    {'character': '网', 'confidence': 0.99991}]},
#  {'item': '',
#   'itemcoord': [{'height': 15, 'width': 91, 'x': 309, 'y': 225}],
#   'itemstring': 'www. kf. cn',
#   'words': [{'character': 'w', 'confidence': 0.997295},
#    {'character': 'w', 'confidence': 0.998897},
#    {'character': 'w', 'confidence': 0.989015},
#    {'character': '.', 'confidence': 0.999946},
#    {'character': '', 'confidence': 1},
#    {'character': 'k', 'confidence': 0.998835},
#    {'character': 'f', 'confidence': 0.999787},
#    {'character': '.', 'confidence': 0.989205},
#    {'character': '', 'confidence': 1},
#    {'character': 'c', 'confidence': 0.99584},
#    {'character': 'n', 'confidence': 0.997517}]},
#  {'item': '',
#   'itemcoord': [{'height': 16, 'width': 108, 'x': 480, 'y': 224}],
#   'itemstring': '41120170004',
#   'words': [{'character': '4', 'confidence': 0.999936},
#    {'character': '1', 'confidence': 0.999286},
#    {'character': '1', 'confidence': 0.99935},
#    {'character': '2', 'confidence': 0.999862},
#    {'character': '0', 'confidence': 0.999965},
#    {'character': '1', 'confidence': 0.999922},
#    {'character': '7', 'confidence': 0.999917},
#    {'character': '0', 'confidence': 0.999802},
#    {'character': '0', 'confidence': 0.999892},
#    {'character': '0', 'confidence': 0.99993},
#    {'character': '4', 'confidence': 0.999971}]},
#  {'item': '',
#   'itemcoord': [{'height': 8, 'width': 92, 'x': 310, 'y': 236}],
#   'itemstring': 'wwww. w ww',
#   'words': [{'character': 'w', 'confidence': 0.989961},
#    {'character': 'w', 'confidence': 0.909356},
#    {'character': 'w', 'confidence': 0.92085},
#    {'character': 'w', 'confidence': 0.480899},
#    {'character': '.', 'confidence': 0.813847},
#    {'character': '', 'confidence': 1},
#    {'character': 'w', 'confidence': 0.453094},
#    {'character': '', 'confidence': 1},
#    {'character': 'w', 'confidence': 0.336265},
#    {'character': 'w', 'confidence': 0.350819}]},
#  {'item': '',
#   'itemcoord': [{'height': 15, 'width': 10, 'x': 63, 'y': 271}],
#   'itemstring': '5',
#   'words': [{'character': '5', 'confidence': 0.998644}]},
#  {'item': '',
#   'itemcoord': [{'height': 20, 'width': 58, 'x': 163, 'y': 269}],
#   'itemstring': '映象网',
#   'words': [{'character': '映', 'confidence': 0.999786},
#    {'character': '象', 'confidence': 0.999963},
#    {'character': '网', 'confidence': 0.999892}]},
#  {'item': '',
#   'itemcoord': [{'height': 14, 'width': 100, 'x': 304, 'y': 274}],
#   'itemstring': 'www. hnr. cn',
#   'words': [{'character': 'w', 'confidence': 0.979171},
#    {'character': 'w', 'confidence': 0.983589},
#    {'character': 'w', 'confidence': 0.987005},
#    {'character': '.', 'confidence': 0.649214},
#    {'character': '', 'confidence': 1},
#    {'character': 'h', 'confidence': 0.998526},
#    {'character': 'n', 'confidence': 0.918544},
#    {'character': 'r', 'confidence': 0.997664},
#    {'character': '.', 'confidence': 0.997147},
#    {'character': '', 'confidence': 1},
#    {'character': 'c', 'confidence': 0.969669},
#    {'character': 'n', 'confidence': 0.991649}]},
#  {'item': '',
#   'itemcoord': [{'height': 17, 'width': 109, 'x': 479, 'y': 271}],
#   'itemstring': '41120170005',
#   'words': [{'character': '4', 'confidence': 0.999847},
#    {'character': '1', 'confidence': 0.999596},
#    {'character': '1', 'confidence': 0.998798},
#    {'character': '2', 'confidence': 0.99877},
#    {'character': '0', 'confidence': 0.999853},
#    {'character': '1', 'confidence': 0.999831},
#    {'character': '7', 'confidence': 0.999083},
#    {'character': '0', 'confidence': 0.999853},
#    {'character': '0', 'confidence': 0.999921},
#    {'character': '0', 'confidence': 0.999948},
#    {'character': '5', 'confidence': 0.999868}]}]
