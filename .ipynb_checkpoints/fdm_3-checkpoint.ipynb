# %% [markdown]
# # 基本设置

# %%
import os
import re
import sys
import datetime as dt

today = dt.datetime.now().strftime('%Y%m%d')
names = locals()

import numpy as np
import warnings
warnings.filterwarnings('ignore') # 为了整洁，去除弹出的warnings

import pandas as pd
pd.set_option('display.max_colwidth',1000) # 显示列数
pd.set_option('precision', 3) # 设置精度
pd.set_option('display.float_format', lambda x:'%.3f' %x) # 不采用科学计数法显示

import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib.gridspec as gridspec
from matplotlib.artist import setp
# %matplotlib inline

from sqlalchemy import create_engine
from pandas.io import sql

from impala.dbapi import connect
from impala.util import as_pandas

from quilt.data.ResidentMario import missingno_data
import missingno as msno

pyfile_folder = r'D:\XH\Python_Project\Proj_2\files'
data_folder = r'D:\XH\Python_Project\Proj_2\data\ETL_data'
result_folder = r'D:\XH\Python_Project\Proj_2\result\ETL_result'

os.chdir(pyfile_folder)
sys.path.append(pyfile_folder)

from Tookits import specific_func  
from Tookits import cal_func

specific_func.set_ch()

# %% [markdown]
# ## 一些函数

# %%
def plot_color_table(data, fontsize = 10):
    '''
    显示带颜色的表格
    data： DataFrame
    '''
    vals = np.around(data.values,3)
    normal = colors.Normalize(vals.min()-1, vals.max()+1)
    
    fig = plt.figure()
    ax = fig.add_subplot(111, frameon=True, xticks=[], yticks=[])
    ax.spines['top'].set_visible(False) #去掉上边框
    ax.spines['bottom'].set_visible(False) #去掉下边框
    ax.spines['left'].set_visible(False) #去掉左边框
    ax.spines['right'].set_visible(False) #去掉右边框
    
    the_table=plt.table(cellText=vals, cellLoc='center', 
                        cellColours=plt.cm.Blues(normal(vals)), 
                        rowLabels=data.index,  rowColours=None, rowLoc='left', 
                        colLabels=data.columns,colColours=None, colLoc='center', 
                        colWidths = None, 
                        loc='center', bbox=[0, 0, int(data.shape[1]/5) + 1, 
                                            int(data.shape[0]/5) + 1] )  
                                        # [left, bottom, width, height]\
    the_table.auto_set_font_size(False)
    the_table.set_fontsize(fontsize)

# %%
def plot_stat_fig(data_1,data_2,data_3,data_4,data_5,kind = 'boxplot'):
    fig = plt.subplots(figsize = (16,12))
    gs = gridspec.GridSpec(2,16)
    fontsize = 30
    label_fontsize = 25
    ticklabel_fontsize = 15

    def get_plot(data, title = None, kind = 'barplot'):
        if kind == 'barplot':
            sns.barplot(data = data, ax=ax)   
        elif kind == 'boxplot':
            sns.boxplot(data = data, ax=ax) 
        elif kind == 'violinplot':
            sns.violinplot(data = data, ax=ax)         
        elif kind == 'stripplot':
            sns.stripplot(data = data, ax=ax, jitter=True) 
        ax.set_title(title, fontsize = fontsize)

    for i in range(5):
        i = i + 1
        if i == 1 :
            ax = plt.subplot(gs[0,:])
            # sns.barplot(data = distance_data_1, ax=ax)
            get_plot(data_1, title = 'd_1', kind = kind)            
        elif i == 2:
            ax = plt.subplot(gs[1,:6])
            get_plot(data_2, title = 'd_2', kind = kind)
            ax.set_ylabel('Mean', fontsize = label_fontsize)
        elif i == 3:
            ax = plt.subplot(gs[1,6:12])
            get_plot(data_3, title = 'd_3', kind = kind)
            ax.set_title('d_3', fontsize = fontsize) 
        elif i == 4:
            ax = plt.subplot(gs[1,12:14])
            get_plot(data_4, title = 'd_4', kind = kind)
        elif i == 5:
            ax = plt.subplot(gs[1,14:])
            get_plot(data_5, title = 'd_5', kind = kind)

        setp(ax.get_yticklabels(), fontsize = ticklabel_fontsize)
        ax.set_xticks(ax.get_xticks() - [0.5])
        setp(ax.get_xticklabels(), fontsize = ticklabel_fontsize, rotation = 45)
        ax.tick_params(width = 0,length = 0)    

    plt.subplots_adjust(left=None, bottom=None, right=None, 
                        top=None, wspace = 6, hspace = 0.6) 
    plt.show()

# %%
def plot_bar_table(rows, cols, col_list, rawdata):
    #rows = 2
    #cols = 3
    num = 0

    fig,axs = plt.subplots(rows,cols, figsize = (15,12))

    for i in range(rows):
        for j in range(cols):
            col = col_list[num]
            data = rawdata[col].value_counts()

            col_labels = ['Freq']
            row_labels = [[x] for x in data.index.tolist()]
            table_vals = [[x] for x in data.values.tolist()]
            row_colors = sns.diverging_palette(220, 20, n = data.shape[0]) 

            my_table = axs[i,j].table(cellText=table_vals, colWidths=[0.2],
                                 rowLabels=row_labels, colLabels=col_labels,
                                 rowColours=row_colors, loc='best',
                                     )#bbox = [0.5,0.6,0.3,0.3]

            axs[i,j].bar(data.index.tolist(), 
                         data.values.tolist(), 
                         color = row_colors, width = 0.3)
            axs[i,j].set_title(col, fontsize = 20)
            # setp(ax.get_yticklabels(), fontsize = ticklabel_fontsize)
            # axs[i,j].set_xticks(axs[i,j].get_xticks() - [0.5])
            setp(axs[i,j].get_xticklabels(), fontsize = 10, rotation = 45)
            axs[i,j].tick_params(width = 0,length = 0)             

            num += 1

    plt.subplots_adjust(left=None, bottom=None, right=None, 
                        top=None, wspace = None, hspace = 0.4) 
    plt.show()

# %% [markdown]
# # 导入数据

# %% [markdown]
# ## 预测变量导入

# %%
score_file = data_folder + '\\name_num.txt'
fid = open(score_file, 'r+', encoding = 'utf-8')
score_data = fid.readlines()
fid.close()

score_data = pd.DataFrame(score_data, columns = ['name_province_score'])
score_data = score_data.applymap(lambda x: x.replace('\n', ''))
score_data['company_name'] = score_data.applymap(lambda x: x.split('_')[0])
score_data['province'] = score_data['name_province_score'].apply(lambda x: x.split('_')[2])
score_data['score'] = score_data['province'].str.findall(r'\d+')
score_data['score'] = score_data['score'].apply(lambda x: x[0]).astype(float)
print(score_data.shape)
score_data.head()
# Out:
# (1989, 4)
#     name_province_score   company_name province  score
# 0   龙福环能科技股份有限公司__山东95分   龙福环能科技股份有限公司    山东95分 95.000
# 1   龙口龙泵燃油喷射有限公司__山东72分   龙口龙泵燃油喷射有限公司    山东72分 72.000
# 2  龙口科诺尔玻璃科技有限公司__山东84分  龙口科诺尔玻璃科技有限公司    山东84分 84.000
# 3     龙口金正机械有限公司__山东84分     龙口金正机械有限公司    山东84分 84.000
# 4     龙口隆基三泵有限公司__山东74分     龙口隆基三泵有限公司    山东74分 74.000

# %%
score_data = score_data[['company_name','score']]
score_data['score'].plot.kde()
score_data['score'].describe()
# Out:
# count   1989.000
# mean      72.521
# std       15.261
# min        0.000
# 25%       61.000
# 50%       72.000
# 75%       85.000
# max       99.000
# Name: score, dtype: float64

# %% [markdown]
# ## 表与字段

# %%
config_file = data_folder + '\\数据流向 3 FDM.xlsx'
config_data = pd.read_excel(config_file)
config_data['sdm_表名'].fillna(method = 'ffill', inplace = True)
config_data['是否先去重'].fillna(method = 'ffill', inplace = True)
configs = config_data[['fdm_字段名', 'fdm_字段解释', '是否先去重', 'sdm_表名']]
print(configs.shape)
configs.tail()
# Out:
# (58, 4)
#                fdm_字段名    fdm_字段解释  是否先去重                        sdm_表名
# 53     comp_ent_number        竞品个数  1.000  sdm_company_comp_ent_produce
# 54      business_level        海关评级  1.000     sdm_company_custom_rating
# 55      monitor_number        监控次数  1.000   sdm_company_environ_monitor
# 56     ind_cred_number      信用评价次数  1.000   sdm_company_ind_cred_record
# 57  last_credit_rating  最近一次行业信用等级  1.000   sdm_company_ind_cred_record

# %%
table_list = configs[['是否先去重','sdm_表名']].drop_duplicates()
print(configs['sdm_表名'].unique().shape)
table_list
# Out:
# (30,)
#     是否先去重                           sdm_表名
# 0   0.000  sdm_company_base_business_merge
# 11  0.000    sdm_company_base_contact_info
# 14  1.000               sdm_company_branch
# 15  1.000      sdm_company_business_change
# 18  1.000       sdm_company_promoters_info
# 20  1.000       sdm_company_senior_manager
# 21  1.000        sdm_company_court_session
# 22  1.000      sdm_company_execute_persons
# 25  1.000     sdm_company_executive_punish
# 26  1.000    sdm_company_bidding_informate
# 28  1.000     sdm_company_chattel_mortgage
# 29  0.000  sdm_company_imp_exp_credit_info
# 35  1.000      sdm_company_operate_anomaly
# 36  1.000              sdm_company_produce
# 39  1.000     sdm_company_recruitment_info
# 40  1.000   sdm_company_stock_right_target
# 42  1.000   sdm_company_tax_arrears_notice
# 43  1.000           sdm_company_tax_rating
# 45  1.000        sdm_company_annual_report
# 46  1.000          sdm_company_patent_info
# 47  1.000          sdm_company_soft_patent
# 48  1.000            sdm_company_trademark
# 49  1.000          sdm_company_web_filings
# 50  1.000         sdm_company_works_patent
# 51  1.000  sdm_company_outbound_investment
# 52  1.000         sdm_company_agri_produce
# 53  1.000     sdm_company_comp_ent_produce
# 54  1.000        sdm_company_custom_rating
# 55  1.000      sdm_company_environ_monitor
# 56  1.000      sdm_company_ind_cred_record

# %% [markdown]
# ## 企业评分数据集

# %%
credit_scroe = pd.DataFrame()
num = 0
merge_field = 'company_name'

for [flag, sdm_table_name] in list(table_list.values):
    num +=1
    print('* 读取第 %s 张表：'%str(num), sdm_table_name)
    fields = configs[configs['sdm_表名'] == sdm_table_name]['fdm_字段名'].tolist()
    if merge_field not in fields:fields.append(merge_field)
    # if 'distinct_name' in fields:fields.remove('distinct_name')
    
    table_path = result_folder +  '\\sdm_2\\csv_data\\' + sdm_table_name + '.csv'
    tmp_data = pd.read_csv(table_path, sep='^')
    names['%s'%sdm_table_name] = tmp_data[fields]
    if flag == 1:
        names['%s'%sdm_table_name] = names['%s'%sdm_table_name].drop_duplicates(subset = merge_field)
    
    if num == 1:
        to_add_num = 0
        credit_scroe = names['%s'%sdm_table_name]
    else :
        to_add_num = credit_scroe.shape[0]
        credit_scroe = pd.merge(credit_scroe, names['%s'%sdm_table_name],
                               on = merge_field, how = 'left')
    
    print('    -- 数据维度：', names['%s'%sdm_table_name].shape)
    print('    -- 融合后数据：维度', credit_scroe.shape, 
          '  增加量：', credit_scroe.shape[0] - to_add_num)
    
    del tmp_data
# Out:
# * 读取第 1 张表： sdm_company_base_business_merge
#     -- 数据维度： (14091, 11)
#     -- 融合后数据：维度 (14091, 11)   增加量： 14091
# * 读取第 2 张表： sdm_company_base_contact_info
#     -- 数据维度： (17292, 4)
#     -- 融合后数据：维度 (14091, 14)   增加量： 0
# * 读取第 3 张表： sdm_company_branch
#     -- 数据维度： (24505, 2)
#     -- 融合后数据：维度 (14091, 15)   增加量： 0
# * 读取第 4 张表： sdm_company_business_change
#     -- 数据维度： (708, 4)
#     -- 融合后数据：维度 (14091, 18)   增加量： 0
# * 读取第 5 张表： sdm_company_promoters_info
#     -- 数据维度： (135702, 3)
#     -- 融合后数据：维度 (14091, 20)   增加量： 0
# * 读取第 6 张表： sdm_company_senior_manager
#     -- 数据维度： (16626, 2)
#     -- 融合后数据：维度 (14091, 21)   增加量： 0
# * 读取第 7 张表： sdm_company_court_session
#     -- 数据维度： (2324, 2)
#     -- 融合后数据：维度 (14091, 22)   增加量： 0
# * 读取第 8 张表： sdm_company_execute_persons
#     -- 数据维度： (21912, 4)
#     -- 融合后数据：维度 (14091, 25)   增加量： 0
# * 读取第 9 张表： sdm_company_executive_punish
#     -- 数据维度： (3816, 2)
#     -- 融合后数据：维度 (14091, 26)   增加量： 0
# * 读取第 10 张表： sdm_company_bidding_informate
#     -- 数据维度： (1432, 3)
#     -- 融合后数据：维度 (14091, 28)   增加量： 0
# * 读取第 11 张表： sdm_company_chattel_mortgage
#     -- 数据维度： (2865, 2)
#     -- 融合后数据：维度 (14091, 29)   增加量： 0
# * 读取第 12 张表： sdm_company_imp_exp_credit_info
#     -- 数据维度： (5057, 7)
#     -- 融合后数据：维度 (14091, 35)   增加量： 0
# * 读取第 13 张表： sdm_company_operate_anomaly
#     -- 数据维度： (1598, 2)
#     -- 融合后数据：维度 (14091, 36)   增加量： 0
# * 读取第 14 张表： sdm_company_produce
#     -- 数据维度： (211, 4)
#     -- 融合后数据：维度 (14091, 39)   增加量： 0
# * 读取第 15 张表： sdm_company_recruitment_info
#     -- 数据维度： (141300, 2)
#     -- 融合后数据：维度 (14091, 40)   增加量： 0
# * 读取第 16 张表： sdm_company_stock_right_target
#     -- 数据维度： (1327, 3)
#     -- 融合后数据：维度 (14091, 42)   增加量： 0
# * 读取第 17 张表： sdm_company_tax_arrears_notice
#     -- 数据维度： (3097, 2)
#     -- 融合后数据：维度 (14091, 43)   增加量： 0
# * 读取第 18 张表： sdm_company_tax_rating
#     -- 数据维度： (5191, 3)
#     -- 融合后数据：维度 (14091, 45)   增加量： 0
# * 读取第 19 张表： sdm_company_annual_report
#     -- 数据维度： (13093, 2)
#     -- 融合后数据：维度 (14091, 46)   增加量： 0
# * 读取第 20 张表： sdm_company_patent_info
#     -- 数据维度： (19161, 2)
#     -- 融合后数据：维度 (14091, 47)   增加量： 0
# * 读取第 21 张表： sdm_company_soft_patent
#     -- 数据维度： (658, 2)
#     -- 融合后数据：维度 (14091, 48)   增加量： 0
# * 读取第 22 张表： sdm_company_trademark
#     -- 数据维度： (5666, 2)
#     -- 融合后数据：维度 (14091, 49)   增加量： 0
# * 读取第 23 张表： sdm_company_web_filings
#     -- 数据维度： (5871, 2)
#     -- 融合后数据：维度 (14091, 50)   增加量： 0
# * 读取第 24 张表： sdm_company_works_patent
#     -- 数据维度： (467, 2)
#     -- 融合后数据：维度 (14091, 51)   增加量： 0
# * 读取第 25 张表： sdm_company_outbound_investment
#     -- 数据维度： (77414, 2)
#     -- 融合后数据：维度 (14091, 52)   增加量： 0
# * 读取第 26 张表： sdm_company_agri_produce
#     -- 数据维度： (365, 2)
#     -- 融合后数据：维度 (14091, 53)   增加量： 0
# * 读取第 27 张表： sdm_company_comp_ent_produce
#     -- 数据维度： (272, 2)
#     -- 融合后数据：维度 (14091, 54)   增加量： 0
# * 读取第 28 张表： sdm_company_custom_rating
#     -- 数据维度： (4736, 2)
#     -- 融合后数据：维度 (14091, 55)   增加量： 0
# * 读取第 29 张表： sdm_company_environ_monitor
#     -- 数据维度： (326, 2)
#     -- 融合后数据：维度 (14091, 56)   增加量： 0
# * 读取第 30 张表： sdm_company_ind_cred_record
#     -- 数据维度： (394, 3)
#     -- 融合后数据：维度 (14091, 58)   增加量： 0

# %%
credit_scroe = credit_scroe.replace('EEEEE', np.nan)

# %% [markdown]
# ## 字段分类

# %% [markdown]
# ### 称名数据

# %%
nominal_col_1 = ['chanle_id', 'company_name', 'company_operat_state', 'province_name',
                 'distinct_name', 'county_name', 'category_name','category_code', 
                 'company_main_type_name', 'bidding_area','company_annual_report', 
                 'company_economic_region', 'company_oper_class', 'company_spe_trade_area',
                 'company_produce_calss', 'company_produce_indus', ]
nominal_data_1 = credit_scroe[nominal_col_1]
print(nominal_data_1.shape)
nominal_data_1.describe().T
# Out:
# (14091, 16)
#                          count unique                                   top  \
# chanle_id                14091  14091  0351ae40-cd7f-431c-90f7-d8b7a95cadb6
# company_name             14091  14078                           威海市丰源装饰有限公司
# company_operat_state     13968      4                                    在营
# province_name            14089      1                                   山东省
# distinct_name            13691     17                                   威海市
# county_name               7460    132                                   环翠区
# category_name            13961     19                                   制造业
# category_code            13961     19                                     C
# company_main_type_name   13968     13                           内资公司_有限责任公司
# bidding_area               816      4                                    SD
# company_annual_report     4159      5                                   未报送
# company_economic_region   4159      6                                一般经济区域
# company_oper_class        4159      4                               进出口收发货人
# company_spe_trade_area    4158      1                                 非特殊区域
# company_produce_calss       42      2                                    应用
# company_produce_indus       42     12                                    生活
#
#                           freq
# chanle_id                    1
# company_name                 3
# company_operat_state     12929
# province_name            14089
# distinct_name             4632
# county_name                939
# category_name             5579
# category_code             5579
# company_main_type_name   11827
# bidding_area               793
# company_annual_report     3139
# company_economic_region   3863
# company_oper_class        4129
# company_spe_trade_area    4158
# company_produce_calss       40
# company_produce_indus       12

# %%
for ind, col in enumerate(nominal_data_1.columns.tolist()):
    print('-- %d  %s ：'%(ind +1, col), 
          nominal_data_1[col].unique().shape, 
          nominal_data_1[col].unique())
# Out:
# -- 1  chanle_id ： (14091,) ['3db30b86-0c2d-4a2f-b3b3-094407e6d571'
#  '6d47b70b-7631-4718-a9d9-7e1339456f2a'
#  'c1296bea-4ba4-4a7c-a798-b20cee5097be' ...,
#  '5bd619ec-a589-4611-a2f4-1f8042bd30ff'
#  'f510becc-f13e-42fc-b5b8-46680108274f'
#  '12633b14-3ed2-4a87-ba94-fa56f3a448a0']
# -- 2  company_name ： (14078,) ['龙福环能科技股份有限公司' '龙口龙泵燃油喷射有限公司' '龙口科诺尔玻璃科技有限公司' ..., '山东正昊中和建设工程服务有限公司'
#  '中节能（山东）投资发展公司' '山东凯顺汽车销售有限公司']
# -- 3  company_operat_state ： (5,) ['在营' '吊销' '注销' nan '迁出']
# -- 4  province_name ： (2,) ['山东省' nan]
# -- 5  distinct_name ： (18,) ['滨州市' '烟台市' nan '济南市' '威海市' '济宁市' '德州市' '东营市' '青岛市' '聊城市' '潍坊市' '菏泽市'
#  '临沂市' '莱芜市' '淄博市' '日照市' '枣庄市' '泰安市']
# -- 6  county_name ： (133,) [nan '龙口市' '市中区' '齐河县' '邹平县' '黄岛区' '荣成市' '东明县' '鱼台县' '寿光市' '高青县' '高密市'
#  '高唐县' '城阳区' '潍城区' '沂水县' '青州市' '市北区' '崂山区' '即墨市' '胶州市' '李沧区' '市南区' '莱西市'
#  '平度市' '阳谷县' '平原县' '阳信县' '长岛县' '环翠区' '兰山区' '临沭县' '金乡县' '鄄城县' '郯城县' '郓城县'
#  '邹城市' '费县' '诸城市' '利津县' '蓬莱市' '历城区' '蒙阴县' '牡丹区' '单县' '莱阳市' '莱城区' '钢城区'
#  '莱州市' '莒县' '莘县' '莒南县' '茌平县' '昌乐县' '东营区' '临邑县' '肥城市' '滕州市' '冠县' '东阿县'
#  '东昌府区' '章丘市' '汶上县' '栖霞市' '禹城市' '广饶县' '张店区' '招远市' '芝罘区' '牟平区' '莱山区' '海阳市'
#  '福山区' '乳山市' '寒亭区' '昌邑市' '奎文区' '坊子区' '临朐县' '安丘市' '滨城区' '博兴县' '无棣县' '临淄区'
#  '桓台县' '淄川区' '周村区' '博山区' '沂源县' '梁山县' '任城区' '曲阜市' '嘉祥县' '泗水县' '兖州区' '长清区'
#  '平阴县' '济阳县' '天桥区' '槐荫区' '历下区' '商河县' '宁阳县' '泰山区' '河东区' '沂南县' '宁津县' '武城县'
#  '台儿庄区' '薛城区' '峄城区' '山亭区' '曹县' '岚山区' '东港区' '新泰市' '成武县' '惠民县' '德城区' '庆云县'
#  '陵城区' '乐陵市' '微山县' '平邑县' '巨野县' '兰陵县' '河口区' '罗庄区' '临清市' '东平县' '文登区'
#  '临沂市_市辖区' '夏津县']
# -- 7  category_name ： (20,) ['制造业' '批发和零售业' '交通运输、仓储和邮政业' '信息传输、软件和信息技术服务业' '水利、环境和公共设施管理业' '租赁和商务服务业'
#  '房地产业' '金融业' '建筑业' '农、林、牧、渔业' '电力、热力、燃气及水生产和供应业' '采矿业' '住宿和餐饮业' '教育' nan
#  '科学研究和技术服务业' '居民服务、修理和其他服务业' '文化、体育和娱乐业' '国际组织' '卫生和社会工作']
# -- 8  category_code ： (20,) ['C' 'F' 'G' 'I' 'N' 'L' 'K' 'J' 'E' 'A' 'D' 'B' 'H' 'P' nan 'M' 'O' 'R'
#  'T' 'Q']
# -- 9  company_main_type_name ： (14,) ['内资公司_股份有限公司' '内资公司_有限责任公司' '外商投资企业_有限责任公司' '内资企业法人' '内资分公司_有限责任公司'
#  '港澳台投资企业_有限责任公司' '外商投资企业_股份有限公司' nan '内资非法人企业_非公司私营企业_内资非公司企业分支机构'
#  '内资分公司_股份有限公司' '港澳台投资企业_股份有限公司' '其他类型' '外商投资企业_其他' '港澳台分公司']
# -- 10  bidding_area ： (5,) [nan 'SD' 'ZJ' 'UN' 'SC']
# -- 11  company_annual_report ： (6,) ['未报送' '已报送' nan '超期未报送' '超期报送' '不需要']
# -- 12  company_economic_region ： (7,) ['一般经济区域' nan '保税区' '经济技术开发全区' '高新技术产业开发区' '保税港区、综合保税区' '出口加工区']
# -- 13  company_oper_class ： (5,) ['进出口收发货人' nan '报关企业' '加工生产企业' '临时注册企业']
# -- 14  company_spe_trade_area ： (2,) ['非特殊区域' nan]
# -- 15  company_produce_calss ： (3,) [nan '应用' '游戏']
# -- 16  company_produce_indus ： (13,) [nan '财务' '摄影与录像' '生活' '游戏' '工具' '美食佳饮' '商务' '新闻' '教育' '购物' '社交' '参考']

# %%
nominal_data_1['bidding_area'].value_counts()
# Out:
# SD    793
# UN     21
# SC      1
# ZJ      1
# Name: bidding_area, dtype: int64

# %%
nominal_col_1_1 = ['company_operat_state',  'company_annual_report',
                 'company_economic_region','company_oper_class',
                 'company_spe_trade_area','company_produce_calss']
nominal_data_1_1 = credit_scroe[nominal_col_1].astype(str)

nominal_col_1_2 = ['category_name',  'company_main_type_name',
                 'company_produce_indus','distinct_name']
nominal_data_1_2 = credit_scroe[nominal_col_1].astype(str)

# %%
plot_bar_table(2, 3, nominal_col_1_1, nominal_data_1_1)

# %%
plot_bar_table(2, 2, nominal_col_1_2, nominal_data_1_2)

# %%
nominal_col_2 = ['is_email','is_telephone',  'is_web_site']
nominal_col = nominal_col_1 + nominal_col_2
nominal_data_2 = credit_scroe[nominal_col_2].astype(str)
nominal_data_2['count'] = 1
print(nominal_data_2.shape)
nominal_data_2.pivot_table(values = ["count"], 
                           columns = ["is_web_site"],
                           index = ["is_email","is_telephone"], 
                           fill_value = 0,
                           aggfunc = sum, margins = True)
# Out:
# (14091, 4)
#                           count
# is_web_site                 0.0      1.0     nan       All
# is_email is_telephone
# 0.0      0.0           1121.000   13.000   0.000  1134.000
#          1.0             84.000    4.000   0.000    88.000
# 1.0      0.0              9.000    6.000   0.000    15.000
#          1.0           9298.000 3408.000   0.000 12706.000
# nan      nan              0.000    0.000 148.000   148.000
# All                   10512.000 3431.000 148.000 14091.000

# %%
for ind, col in enumerate(nominal_data_2.columns.tolist()):
    print('-- %d  %s ：'%(ind +1, col), 
          nominal_data_2[col].unique().shape, 
          nominal_data_2[col].unique())
# Out:
# -- 1  is_email ： (3,) ['1.0' '0.0' 'nan']
# -- 2  is_telephone ： (3,) ['1.0' '0.0' 'nan']
# -- 3  is_web_site ： (3,) ['1.0' '0.0' 'nan']
# -- 4  count ： (1,) [1]

# %%
rows = 1
cols = 3
num = 0
fig,axs = plt.subplots(rows,cols, figsize = (15,6))
for j in range(cols):
    col = nominal_col_2[num]
    data = nominal_data_2[col].value_counts()
    data = data.sort_values()

    col_labels = ['Freq']
    row_labels = [[x] for x in data.index.tolist()]
    table_vals = [[x] for x in data.values.tolist()]
    row_colors = sns.diverging_palette(220, 20, n = data.shape[0]) 

    my_table = axs[j].table(cellText=table_vals, # colWidths=[0.2],
                            rowLabels=row_labels, colLabels=col_labels,
                            rowColours=row_colors, # loc = 'best',
                            bbox = [0.25,0.6,0.15,0.3])

    axs[j].bar(data.index.tolist(), data.values.tolist(), 
               color = row_colors, width = 0.3)
    axs[j].set_title(col, fontsize = 20)
    if j == 0:axs[j].set_ylabel('Freq', fontsize = 15)

    num += 1
        
plt.show()

# %% [markdown]
# ### 顺序数据

# %%
order_col = ['execute_perform', 'company_cancellate_no', 'company_credit_level',
             'company_stock_ple_status', 'last_tax_level', 'business_level',
             'last_credit_rating', 'company_initiate_type', 'execute_type']
order_data = credit_scroe[order_col].astype(str)
print(order_data.shape)
data = order_data.describe().T

data
# Out:
# (14091, 9)
#                           count unique  top   freq
# execute_perform           14091      4  nan  12808
# company_cancellate_no     14091      3  nan   9932
# company_credit_level      14091      4  nan  13488
# company_stock_ple_status  14091      3  nan  13092
# last_tax_level            14091      2  nan   9928
# business_level            14091      7  nan  10203
# last_credit_rating        14091      6  nan  13810
# company_initiate_type     14091      3  nan  13630
# execute_type              14091      3  nan  12807

# %%
for ind, col in enumerate(order_data.columns.tolist()):
    print('-- %d  %s ：'%(ind +1, col), 
          order_data[col].unique().shape, 
          order_data[col].unique())
# Out:
# -- 1  execute_perform ： (4,) ['nan' '全部未履行' '部分未履行' '0']
# -- 2  company_cancellate_no ： (3,) ['正常' 'nan' '注销']
# -- 3  company_credit_level ： (4,) ['nan' '一般信用企业' '高级认证企业' '一般认证企业']
# -- 4  company_stock_ple_status ： (3,) ['有效' 'nan' '无效']
# -- 5  last_tax_level ： (2,) ['A' 'nan']
# -- 6  business_level ： (7,) ['0' 'B' 'nan' '1' 'A' 'D' 'C']
# -- 7  last_credit_rating ： (6,) ['AAA' 'nan' 'A' 'AA' 'BBB' 'AA+']
# -- 8  company_initiate_type ： (3,) ['nan' '1.0' '2.0']
# -- 9  execute_type ： (3,) ['nan' '1.0' '0.0']

# %%
plot_bar_table(3, 3, order_col, order_data)

# %% [markdown]
# ### 等距与等比

# %%
col_list = credit_scroe.columns.tolist()
distance_col = []
distance_col_1 = []
distance_col_2 = []
distance_col_3 = []
distance_col_4 = []
distance_col_5 = []
    
for col in col_list:
    if (col not in nominal_col) & (col not in order_col):
        distance_col.append(col)
        if credit_scroe[col].max() < 100:
            distance_col_1.append(col)
        elif (credit_scroe[col].max() > 100) & (credit_scroe[col].max() < 1000):
            distance_col_2.append(col)
        elif (credit_scroe[col].max() > 1000) & (credit_scroe[col].max() < 10000):
            distance_col_3.append(col)
        elif (credit_scroe[col].max() > 10000) & (credit_scroe[col].max() < 100000):
            distance_col_4.append(col)            
        else :
            distance_col_5.append(col)
            
distance_data = credit_scroe[distance_col]
distance_data_1 = credit_scroe[distance_col_1]
distance_data_2 = credit_scroe[distance_col_2]
distance_data_3 = credit_scroe[distance_col_3]
distance_data_4 = credit_scroe[distance_col_4]
distance_data_5 = credit_scroe[distance_col_5]

print('* distance_col_1：', distance_data_1.shape, distance_col_1)
print('* distance_col_2：', distance_data_2.shape, distance_col_2)
print('* distance_col_3：', distance_data_3.shape, distance_col_3)
print('* distance_col_4：', distance_data_4.shape, distance_col_4)
print('* distance_col_5：', distance_data_5.shape, distance_col_5)
# Out:
# * distance_col_1： (14091, 17) ['change_project_number', 'change_number', 'shareho_number', 'court_session_number', 'execute_person_number', 'punish_number', 'chattel_number', 'annomaly_number', 'produce_number', 'tax_arrears_number', 'tax_rating_number', 'report_number', 'web_filings_number', 'agri_number', 'comp_ent_number', 'monitor_number', 'ind_cred_number']
# * distance_col_2： (14091, 6) ['branch_company_number', 'employee_number', 'recruitment_number', 'stock_right_number', 'soft_number', 'outbound_investment_number']
# * distance_col_3： (14091, 5) ['last_change_to_now', 'bidding_number', 'patent_number', 'trademark_number', 'works_number']
# * distance_col_4： (14091, 1) ['exist_days']
# * distance_col_5： (14091, 1) ['company_regis_capital']

# %% [markdown]
# #### 所有变量--相关矩阵

# %%
# 相关
fig, ax = plt.subplots(figsize=(22, 15))
cmap = sns.diverging_palette(220, 20, n=20)
sns.heatmap(distance_data.corr(), cmap = cmap,
            annot = True, annot_kws={'size':8, 'weight':'bold', 'color':'blue'}, 
            cbar = True, cbar_kws ={'orientation':'vertical',
                                    'pad':0.005, 'fraction':0.45}, 
            vmax = 1, vmin = -1, linewidths=.5, fmt="0.2f")
plt.yticks(fontsize = 15)
plt.xticks(fontsize = 15)

# colorbar
cax = plt.gcf().axes[-1]
cax.tick_params(labelsize = 10, direction = 'out', 
                length = 6, width = 2, color = 'r') # tick & ticklabel

# %% [markdown]
# #### 所有变量--散点、KDE、回归

# %%
g = sns.PairGrid(distance_data_1)
g.map_upper(plt.scatter)
g.map_lower(sns.regplot)
g.map_diag(sns.kdeplot)

# %%
g = sns.PairGrid(distance_data_2)
g.map_upper(plt.scatter)
g.map_lower(sns.regplot)
g.map_diag(sns.kdeplot)

# %%
g = sns.PairGrid(distance_data_3)
g.map_upper(plt.scatter)
g.map_lower(sns.regplot)
g.map_diag(sns.kdeplot)

# %%
sns.jointplot(x="company_regis_capital", y="exist_days", 
              data=pd.concat([distance_data_4, distance_data_5], axis = 1), 
              kind="reg")

# %% [markdown]
# #### 单个变量--describe

# %%
distance_data.describe().T
# Out:
#                                count     mean       std     min      25%  \
# company_regis_capital      14091.000 8921.216 58169.562   0.000  240.000
# exist_days                 13968.000 4490.487  2361.820 132.000 2666.000
# branch_company_number        102.000   19.784    54.718   1.000    1.250
# change_project_number        671.000    2.838     1.815   1.000    1.000
# change_number                671.000    3.466     2.718   1.000    2.000
# last_change_to_now           671.000  533.844   501.206   1.000  175.000
# shareho_number               461.000    2.970     4.383   1.000    1.000
# employee_number            13759.000    3.940     7.460   1.000    2.000
# court_session_number         539.000    2.263     4.835   1.000    1.000
# execute_person_number       1284.000    3.500     5.931   1.000    1.000
# punish_number                 72.000    1.139     0.348   1.000    1.000
# bidding_number              1253.000   14.355   102.236   1.000    1.000
# chattel_number              2395.000    4.386     5.100   1.000    1.000
# annomaly_number             1151.000    1.732     0.882   1.000    1.000
# produce_number               121.000    1.364     1.017   1.000    1.000
# recruitment_number          3846.000    9.451    13.569   1.000    2.000
# stock_right_number           999.000    3.344     6.418   1.000    1.000
# tax_arrears_number          2945.000    2.208     5.011   1.000    1.000
# tax_rating_number           4163.000    1.874     0.978   1.000    1.000
# report_number              12883.000    3.787     0.605   1.000    4.000
# patent_number               2016.000   21.603   118.582   1.000    2.000
# soft_number                  491.000    8.356    21.536   1.000    2.000
# trademark_number            4759.000   13.777    54.694   1.000    1.000
# web_filings_number          4688.000    1.333     0.821   1.000    1.000
# works_number                 382.000    8.950    61.975   1.000    1.000
# outbound_investment_number  4802.000    4.687     9.527   1.000    1.000
# agri_number                  344.000    2.247     3.314   1.000    1.000
# comp_ent_number              186.000   11.742     3.820   3.000   10.000
# monitor_number               270.000    4.100     2.360   1.000    2.000
# ind_cred_number              281.000    1.431     0.817   1.000    1.000
#
#                                 50%      75%         max
# company_regis_capital      1000.000 5000.000 4054400.000
# exist_days                 4297.000 5926.000   23730.000
# branch_company_number         4.000   11.750     285.000
# change_project_number         2.000    4.000      14.000
# change_number                 3.000    5.000      31.000
# last_change_to_now          458.000  811.000    7446.000
# shareho_number                1.000    2.000      32.000
# employee_number               2.000    4.000     752.000
# court_session_number          1.000    2.000      56.000
# execute_person_number         2.000    4.000      86.000
# punish_number                 1.000    1.000       2.000
# bidding_number                3.000   10.000    3469.000
# chattel_number                3.000    5.000      83.000
# annomaly_number               2.000    2.000       5.000
# produce_number                1.000    1.000       6.000
# recruitment_number            5.000   11.000     230.000
# stock_right_number            2.000    4.000     121.000
# tax_arrears_number            1.000    1.000      71.000
# tax_rating_number             2.000    3.000       6.000
# report_number                 4.000    4.000       4.000
# patent_number                 7.000   14.250    3357.000
# soft_number                   4.000    7.000     322.000
# trademark_number              3.000    8.000    2303.000
# web_filings_number            1.000    1.000      14.000
# works_number                  1.000    2.000    1068.000
# outbound_investment_number    2.000    5.000     364.000
# agri_number                   1.000    2.000      40.000
# comp_ent_number              10.000   12.000      32.000
# monitor_number                4.000    6.000       8.000
# ind_cred_number               1.000    2.000       6.000

# %% [markdown]
# #### 单个变量--barplot

# %%
plot_stat_fig(distance_data_1,distance_data_2,distance_data_3,
              distance_data_4,distance_data_5,kind = 'barplot')

# %% [markdown]
# #### 单个变量--boxplot

# %%
plot_stat_fig(distance_data_1,distance_data_2,distance_data_3,
              distance_data_4,distance_data_5,kind = 'boxplot')

# %% [markdown]
# #### 单个变量--violinplot

# %%
plot_stat_fig(distance_data_1,distance_data_2,distance_data_3,
              distance_data_4,distance_data_5,kind = 'violinplot')

# %% [markdown]
# #### 单个变量--stripplot

# %%
plot_stat_fig(distance_data_1,distance_data_2,distance_data_3,
              distance_data_4,distance_data_5,kind = 'stripplot')

# %% [markdown]
# ## 探索分析：缺失值

# %%
msno.matrix(credit_scroe)

# %%
msno.bar(credit_scroe, sort = 'ascending')

# %%
msno.heatmap(credit_scroe)

# %%
msno.dendrogram(credit_scroe)

# %% [markdown]
# ## 探索分析：统计

# %% [markdown]
# # 预处理

# %%
nominal_var = nominal_col.copy()
for col in ['company_name', 'chanle_id', 'category_code']:
    nominal_var.remove(col)

model_var = nominal_var + order_col + distance_col

preprocessed_data = credit_scroe[model_var]
 
print(preprocessed_data.shape)
preprocessed_data.columns

# %% [markdown]
# ## 缺失值处理

# %% [markdown]
# ## 极端值处理

# %% [markdown]
# ## 分类变量

# %%
from sklearn import preprocessing

# %%
# Encoding categorical 
def categorical_encode(col_list, data, 
                       one_hot = False, 
                       cat_encode_filepath = None, 
                       old_cat_encode = None, 
                       update_cat_encode = False):
    cat_encode = {}  # 存储编码，以为后用 {'col': {'EEEEE': 0, '非特殊区域': 1}}
    
    for index, col in enumerate(col_list):
        print('* %d'%index, '  -- %s'%col)
        if one_hot:
            dummy_data = pd.get_dummies(data[col], prefix = col, dummy_na = True)
            data = data.join(dummy_data)
            
        else :
            # 空值填充
            data[col] = data[col].fillna('EEEEE').astype(str)

            # 考虑类别标签复用
            if old_cat_encode:
                label_mapping = old_cat_encode[col]
                # 如果新数据多出标签
                if list(np.unique(data[col])) != list(label_mapping.keys()):
                    print('  -- %s  在新数据中有多出类别'%col)
                    if update_cat_encode: # 更新标签
                        label_mapping = {label:idx for idx,label in enumerate(np.unique(data[col]))}
            else :
                label_mapping = {label:idx for idx,label in enumerate(np.unique(data[col]))}
                # inv_label_mapping = {v:k for k,v in label_mapping.items()}  ## 还原  

            cat_encode['%s'%col] = label_mapping        
            data["label_" + col] = data[col].map(label_mapping)        
            # 空值还原
            data["label_" + col] = data["label_" + col].replace(label_mapping['EEEEE'], np.nan)        
        
        data = data.drop(col, axis = 1)
    
    # 保存为二进制文件
    save_filename = 
    pickle.dump(data,open('file_path','wb')) 

    return data
# Out:
#   File "<ipython-input-55-58e072cb8805>", line 39
#     save_filename =
#                     ^
# SyntaxError: invalid syntax

# %%
raw_data = credit_scroe[nominal_var].fillna('EEEEE')
print(raw_data.shape)
raw_data.head()
# data = categorical_encode(nominal_var[:2], raw_data, kind = 'label')

# %%
raw_data['company_annual_report'].value_counts()

# %%
data = categorical_encode(nominal_var[7:8], raw_data)

# %%
data['label_company_annual_report'].value_counts()

# %%
# help(pd.get_dummies)

# %%
pd.get_dummies(raw_data[col], prefix = col, dummy_na = True)

# %%
#class_label = preprocessing.LabelEncoder()
col = 'company_spe_trade_area'
#raw_data[col] = raw_data[col].fillna('EEEEE').astype(str)
#raw_data["label_" + col] = class_label.fit_transform(raw_data[col].values)
list(np.unique(raw_data[col])) == list(label_mapping.keys())

# %%
label_mapping = {label:idx for idx,label in enumerate(np.unique(raw_data[col]))}
# inv_label_mapping = {v:k for k,v in label_mapping.items()}  ## 还原
#raw_data["label_" + col] = data["label"].map(inv_label_mapping)
label_mapping

# %%
list(label_mapping.keys())

# %%
a = {'x':{'y':'u'}}
a['x']['y']

# %%
cat_encode = {}
cat_encode['col'] = label_mapping
cat_encode['col'] = {'EEEEE': 0}
cat_encode

# %%
raw_data.describe().T

# %%
raw_data.head()

# %%
data.head()

# %%
raw_data['company_operat_state'].unique()

# %% [markdown]
# ## 数值变量

# %% [markdown]
# ## 文本变量

# %% [markdown]
# # 特征工程

# %% [markdown]
# ## 标准化（一列变量）、归一化（一行记录）

# %% [markdown]
# # 划分数据集

# %%
credit_scroe = pd.merge(score_data, credit_scroe, 
                        on = 'company_name', how = 'left')
credit_scroe.shape

# %% [markdown]
# # 聚类模型

# %% [markdown]
# ## K-means

# %% [markdown]
# ## Affinity Propagation

# %% [markdown]
# ## Mean Shift

# %% [markdown]
# ## Spectral clustering

# %% [markdown]
# ## Hierarchical clustering

# %% [markdown]
# ## DBSCAN

# %% [markdown]
# ## Birch

# %% [markdown]
# ## EM（最大期望）

# %% [markdown]
# # 聚类模型评价

# %% [markdown]
# ## Adjusted Rand index

# %% [markdown]
# ## Mutual Information based scores

# %% [markdown]
# ## Homogeneity, completeness and V-measure

# %% [markdown]
# ## Fowlkes-Mallows scores

# %% [markdown]
# ## Silhouette Coefficient

# %% [markdown]
# ## Calinski-Harabaz Index

# %% [markdown]
# # 预测模型

# %% [markdown]
# # 预测模型评价
